# %%
import pandas as pd
import numpy as np
import requests
import json
import datetime
import locale

# %% [markdown]
# # API

# %%
base_url = "https://api.pappers.fr/v2/"
api_token = '1d7cafbc883e3a2d6ed4be615b5973b0dc7955dca15d657c'
siret = '34300986600611'

url = f"{base_url}entreprise"

params = {
    "api_token": api_token,
    "siret": siret
}

response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()
    # Process the retrieved data as needed
    print(data)
else:
    print("Error occurred:", response.status_code)
# Out:
# {'siren': '343009866', 'siren_formate': '343 009 866', 'diffusable': True, 'nom_entreprise': 'ADECCO TRAINING', 'personne_morale': True, 'denomination': 'ADECCO TRAINING', 'sigle': None, 'nom': None, 'prenom': None, 'sexe': None, 'siege': {'siret': '34300986600611', 'siret_formate': '343 009 866 00611', 'diffusion_partielle': False, 'nic': '00611', 'numero_voie': 2, 'indice_repetition': None, 'type_voie': 'RUE', 'libelle_voie': 'HENRI LEGAY', 'complement_adresse': None, 'adresse_ligne_1': '2 RUE HENRI LEGAY', 'adresse_ligne_2': None, 'code_postal': '69100', 'ville': 'VILLEURBANNE', 'pays': 'France', 'code_pays': 'FR', 'latitude': 45.759053, 'longitude': 4.916103, 'code_naf': '85.59A', 'libelle_code_naf': "Formation continue d'adultes", 'date_de_creation': '2016-10-03', 'etablissement_employeur': True, 'effectif': 'Entre 20 et 49 salariés', 'effectif_min': 20, 'effectif_max': 49, 'tranche_effectif': '12', 'annee_effectif': 2020, 'etablissement_cesse': False, 'date_cessation': None, 'domiciliation': None, 'siege': True, 'enseigne': 'ADECCO TRAINING', 'nom_commercial': 'ADECCO TRAINING', 'predecesseurs': [{'siret': '34300986600405', 'date': '2016-12-01', 'transfert_siege': True, 'continuite_economique': True}]}, 'rnm': None, 'code_naf': '85.59A', 'libelle_code_naf': "Formation continue d'adultes", 'domaine_activite': 'Enseignement', 'objet_social': "Directement ou indirectement l'activité de formation et de perfectionnement du personnel des entreprises, incluant la formation par l'apprentissage, la création et la gestion d'un centre de formation d'apprentis et d'unités de formation d'apprentissage. Formation des élus et des collectivités territoriales. Prestations de conseil et d'assistance.", 'conventions_collectives': [{'nom': 'Convention collective nationale des organismes de formation', 'idcc': 1516, 'confirmee': True}, {'nom': 'Accord national professionnel relatif aux salariés permanents des entreprises de travail temporaire', 'idcc': 1413, 'confirmee': True}, {'nom': 'Convention collective nationale du personnel des prestataires de services dans le domaine du secteur tertiaire', 'idcc': 2098, 'confirmee': True}], 'date_creation': '1987-10-05', 'date_creation_formate': '05/10/1987', 'entreprise_cessee': False, 'date_cessation': None, 'date_cessation_formate': None, 'associe_unique': False, 'categorie_juridique': '5710', 'forme_juridique': 'SAS, société par actions simplifiée', 'entreprise_employeuse': True, 'societe_a_mission': False, 'effectif': 'Entre 100 et 199 salariés', 'effectif_min': 100, 'effectif_max': 199, 'annee_effectif': 2020, 'tranche_effectif': '22', 'annee_tranche_effectif': 2020, 'capital': 1857820, 'capital_actuel_si_variable': None, 'devise_capital': 'Euros', 'capital_formate': '1 857 820,00 €', 'date_cloture_exercice': '31 Décembre', 'date_cloture_exercice_exceptionnelle': None, 'prochaine_date_cloture_exercice': '2023-12-31', 'prochaine_date_cloture_exercice_formate': '31/12/2023', 'economie_sociale_solidaire': False, 'duree_personne_morale': 99, 'derniere_mise_a_jour_sirene': '2023-06-07', 'derniere_mise_a_jour_rcs': None, 'dernier_traitement': '2023-04-01', 'statut_rcs': 'Inscrit', 'greffe': 'LYON', 'code_greffe': '6901', 'numero_rcs': '343 009 866 R.C.S. Lyon', 'date_immatriculation_rcs': '1987-11-24', 'date_premiere_immatriculation_rcs': '1987-11-24', 'date_debut_activite': None, 'date_debut_premiere_activite': '1987-10-05', 'date_radiation_rcs': None, 'numero_tva_intracommunautaire': 'FR66343009866', 'etablissement': {'siret': '34300986600611', 'siret_formate': '343 009 866 00611', 'diffusion_partielle': False, 'nic': '00611', 'numero_voie': 2, 'indice_repetition': None, 'type_voie': 'RUE', 'libelle_voie': 'HENRI LEGAY', 'complement_adresse': None, 'adresse_ligne_1': '2 RUE HENRI LEGAY', 'adresse_ligne_2': None, 'code_postal': '69100', 'ville': 'VILLEURBANNE', 'pays': 'France', 'code_pays': 'FR', 'latitude': 45.759053, 'longitude': 4.916103, 'code_naf': '85.59A', 'libelle_code_naf': "Formation cont ...

# %%
data
# Out:
# {'siren': '343009866',
#  'siren_formate': '343 009 866',
#  'diffusable': True,
#  'nom_entreprise': 'ADECCO TRAINING',
#  'personne_morale': True,
#  'denomination': 'ADECCO TRAINING',
#  'sigle': None,
#  'nom': None,
#  'prenom': None,
#  'sexe': None,
#  'siege': {'siret': '34300986600611',
#   'siret_formate': '343 009 866 00611',
#   'diffusion_partielle': False,
#   'nic': '00611',
#   'numero_voie': 2,
#   'indice_repetition': None,
#   'type_voie': 'RUE',
#   'libelle_voie': 'HENRI LEGAY',
#   'complement_adresse': None,
#   'adresse_ligne_1': '2 RUE HENRI LEGAY',
#   'adresse_ligne_2': None,
#   'code_postal': '69100',
#   'ville': 'VILLEURBANNE',
#   'pays': 'France',
#   'code_pays': 'FR',
#   'latitude': 45.759053,
#   'longitude': 4.916103,
#   'code_naf': '85.59A',
#   'libelle_code_naf': "Formation continue d'adultes",
#   'date_de_creation': '2016-10-03',
#   'etablissement_employeur': True,
#   'effectif': 'Entre 20 et 49 salariés',
#   'effectif_min': 20,
#   'effectif_max': 49,
#   'tranche_effectif': '12',
#   'annee_effectif': 2020,
#   'etablissement_cesse': False,
#   'date_cessation': None,
#   'domiciliation': None,
#   'siege': True,
#   'enseigne': 'ADECCO TRAINING',
#   'nom_commercial': 'ADECCO TRAINING',
#   'predecesseurs': [{'siret': '34300986600405',
#     'date': '2016-12-01',
#     'transfert_siege': True,
#     'continuite_economique': True}]},
#  'rnm': None,
#  'code_naf': '85.59A',
#  'libelle_code_naf': "Formation continue d'adultes",
#  'domaine_activite': 'Enseignement',
#  'objet_social': "Directement ou indirectement l'activité de formation et de perfectionnement du personnel des entreprises, incluant la formation par l'apprentissage, la création et la gestion d'un centre de formation d'apprentis et d'unités de formation d'apprentissage. Formation des élus et des collectivités territoriales. Prestations de conseil et d'assistance.",
#  'conventions_collectives': [{'nom': 'Convention collective nationale des organismes de formation',
#    'idcc': 1516,
#    'confirmee': True},
#   {'nom': 'Accord national professionnel relatif aux salariés permanents des entreprises de travail temporaire',
#    'idcc': 1413,
#    'confirmee': True},
#   {'nom': 'Convention collective nationale du personnel des prestataires de services dans le domaine du secteur tertiaire',
#    'idcc': 2098,
#    'confirmee': True}],
#  'date_creation': '1987-10-05',
#  'date_creation_formate': '05/10/1987',
#  'entreprise_cessee': False,
#  'date_cessation': None,
#  'date_cessation_formate': None,
#  'associe_unique': False,
#  'categorie_juridique': '5710',
#  'forme_juridique': 'SAS, société par actions simplifiée',
#  'entreprise_employeuse': True,
#  'societe_a_mission': False,
#  'effectif': 'Entre 100 et 199 salariés',
#  'effectif_min': 100,
#  'effectif_max': 199,
#  'annee_effectif': 2020,
#  'tranche_effectif': '22',
#  'annee_tranche_effectif': 2020,
#  'capital': 1857820,
#  'capital_actuel_si_variable': None,
#  'devise_capital': 'Euros',
#  'capital_formate': '1 857 820,00 €',
#  'date_cloture_exercice': '31 Décembre',
#  'date_cloture_exercice_exceptionnelle': None,
#  'prochaine_date_cloture_exercice': '2023-12-31',
#  'prochaine_date_cloture_exercice_formate': '31/12/2023',
#  'economie_sociale_solidaire': False,
#  'duree_personne_morale': 99,
#  'derniere_mise_a_jour_sirene': '2023-06-07',
#  'derniere_mise_a_jour_rcs': None,
#  'dernier_traitement': '2023-04-01',
#  'statut_rcs': 'Inscrit',
#  'greffe': 'LYON',
#  'code_greffe': '6901',
#  'numero_rcs': '343 009 866 R.C.S. Lyon',
#  'date_immatriculation_rcs': '1987-11-24',
#  'date_premiere_immatriculation_rcs': '1987-11-24',
#  'date_debut_activite': None,
#  'date_debut_premiere_activite': '1987-10-05',
#  'date_radiation_rcs': None,
#  'numero_tva_intracommunautaire': 'FR66343009866',
#  'etablissement': {'siret': '34300986600611',
#   'siret_formate': '343 009 866 00611',
#   'diffusion_partielle': False,
#   'nic': '00611',
#   'numero_voie': 2,
#   'indice_repetition': None,
#   'type_voie': 'RUE',
#   'libelle_voie': 'HENRI LEGAY',
#   'complement_adresse': None,
#   'adresse_ligne_1': '2 RUE HENRI LEGAY',
#   'adresse_ligne_2': None,
#   'code_postal': '69100',
#   'ville': 'VILLEURBANNE',
#   'pays': 'France',
#   'code_pays': 'FR',
#   'latitude': 45.759053,
#   'longitude': 4.916103,
#   'code_naf': '85.59A',
#   'libelle_code_naf': "Formation continue d'adultes",
#   'etablissement_employeur': True,
#   'effectif': 'Entre 20 et 49 salariés',
#   'effectif_min': 20,
#   'effectif_max': 49,
#   'tranche_effectif': '12',
#   'annee_effectif': 2020,
#   'date_de_creation': '2016-10-03',
#   'etablissement_cesse': False,
#   'date_cessation': None,
#   'domiciliation': None,
#   'siege': True,
#   'enseigne': 'ADECCO TRAINING',
#   'nom_commercial': 'ADECCO TRAINING',
#   'predecesseurs': [{'siret': '34300986600405',
#     'date': '2016-12-01',
#     'transfert_siege': True,
#     'continuite_economique': True}]},
#  'finances': [{'annee': 2021,
#    'date_de_cloture_exercice': '2021-12-31',
#    'duree_exercice': 12,
#    'chiffre_affaires': 61225938,
#    'chiffre_affaires_export': 19250,
#    'resultat': 3460378,
#    'effectif': None,
#    'marge_brute': 61682881,
#    'excedent_brut_exploitation': 5454618,
#    'resultat_exploitation': 5439710,
#    'taux_croissance_chiffre_affaires': 22.6,
#    'taux_marge_brute': 100.7,
#    'taux_marge_EBITDA': 8.9,
#    'taux_marge_operationnelle': 8.9,
#    'BFR_exploitation': -909659,
#    'BFR_hors_exploitation': 16790668,
#    'BFR': 15881009,
#    'BFR_exploitation_jours_CA': -5.4,
#    'BFR_hors_exploitation_jours_CA': 100.1,
#    'BFR_jours_CA': 94.7,
#    'delai_paiement_clients_jours': 61.2,
#    'delai_paiement_fournisseurs_jours': 85.6,
#    'ratio_stock_CA_jours': 0,
#    'capacite_autofinancement': 3753770,
#    'capacite_autofinancement_CA': 6.1,
#    'fonds_roulement_net_global': 15889293,
#    'couverture_BFR': 1,
#    'tresorerie': 8285,
#    'dettes_financieres': None,
#    'capacite_remboursement': 0,
#    'ratio_endettement': 0,
#    'autonomie_financiere': 49.9,
#    'taux_levier': 0,
#    'etat_dettes_1_an_au_plus': None,
#    'liquidite_generale': None,
#    'couverture_dettes': -275.2,
#    'marge_nette': 5.7,
#    'fonds_propres': 17333969,
#    'rentabilite_fonds_propres': 20,
#    'rentabilite_economique': 10,
#    'valeur_ajoutee': 13576219,
#    'valeur_ajoutee_CA': 22.2,
#    'salaires_charges_sociales': 7448938,
#    'salaires_CA': 12.2,
#    'impots_taxes': 414300},
#   {'annee': 2020,
#    'date_de_cloture_exercice': '2020-12-31',
#    'duree_exercice': 12,
#    'chiffre_affaires': 49921592,
#    'resultat': 2381483,
#    'effectif': 106,
#    'chiffre_affaires_export': 62282,
#    'marge_brute': 50183181,
#    'excedent_brut_exploitation': 4062730,
#    'resultat_exploitation': 3999388,
#    'taux_croissance_chiffre_affaires': -2.8,
#    'taux_marge_brute': 100.5,
#    'taux_marge_EBITDA': 8.1,
#    'taux_marge_operationnelle': 8,
#    'BFR_exploitation': 5314664,
#    'BFR_hors_exploitation': 7137297,
#    'BFR': 12451961,
#    'BFR_exploitation_jours_CA': 38.9,
#    'BFR_hors_exploitation_jours_CA': 52.2,
#    'BFR_jours_CA': 91.1,
#    'delai_paiement_clients_jours': 128.9,
#    'delai_paiement_fournisseurs_jours': 115.5,
#    'ratio_stock_CA_jours': 0,
#    'capacite_autofinancement': 2405800,
#    'capacite_autofinancement_CA': 4.8,
#    'fonds_roulement_net_global': 12459195,
#    'couverture_BFR': 1,
#    'tresorerie': 7235,
#    'dettes_financieres': 1470,
#    'capacite_remboursement': 0,
#    'ratio_endettement': 0,
#    'autonomie_financiere': 41.5,
#    'taux_levier': 0,
#    'etat_dettes_1_an_au_plus': None,
#    'liquidite_generale': None,
#    'couverture_dettes': -386.7,
#    'fonds_propres': 13873590,
#    'marge_nette': 4.8,
#    'rentabilite_fonds_propres': 17.2,
#    'rentabilite_economique': 7.1,
#    'valeur_ajoutee': 10995846,
#    'valeur_ajoutee_CA': 22,
#    'salaires_charges_sociales': 6236459,
#    'salaires_CA': 12.5,
#    'impots_taxes': 352003},
#   {'annee': 2019,
#    'date_de_cloture_exercice': '2019-12-31',
#    'duree_exercice': 12,
#    'chiffre_affaires': 51374984,
#    'resultat': 1111971,
#    'effectif': 120,
#    'chiffre_affaires_export': 12729,
#    'marge_brute': 51947608,
#    'excedent_brut_exploitation': 2272045,
#    'resultat_exploitation': 2012202,
#    'taux_croissance_chiffre_affaires': -7.1,
#    'taux_marge_brute': 101.1,
#    'taux_marge_EBITDA': 4.4,
#    'taux_marge_operationnelle': 3.9,
#    'BFR_exploitation': 3991851,
#    'BFR_hors_exploitation': 6123911,
#    'BFR': 10115762,
#    'BFR_exploitation_jours_CA': 28.4,
#    'BFR_hors_exploitation_jours_CA': 43.5,
#    'BFR_jours_CA': 71.9,
#    'delai_paiement_clients_jours': 116.1,
#    'delai_paiement_fournisseurs_jours': 111.2,
#    'ratio_stock_CA_jours': 0,
#    'capacite_autofinancement': 2007760,
#    'capacite_autofinancement_CA': 3.9,
#    'fonds_roulement_net_global': 10115760,
#    'couverture_BFR': 1,
#    'tresorerie': None,
#    'dettes_financieres': 2699,
#    'capacite_remboursement': 0,
#    'ratio_endettement': 0,
#    'autonomie_financiere': 37.5,
#    'taux_levier': 0,
#    'etat_dettes_1_an_au_plus': 18181049,
#    'liquidite_generale': 1.6,
#    'couverture_dettes': 880.6,
#    'fonds_propres': 11492107,
#    'marge_nette': 2.2,
#    'rentabilite_fonds_propres': 9.7,
#    'rentabilite_economique': 3.6,
#    'valeur_ajoutee': 10808293,
#    'valeur_ajoutee_CA': 21,
#    'salaires_charges_sociales': 7810982,
#    'salaires_CA': 15.2,
#    'impots_taxes': 406553},
#   {'annee': 2018,
#    'date_de_cloture_exercice': '2018-12-31',
#    'duree_exercice': 12,
#    'chiffre_affaires': 55306948,
#    'resultat': 662979,
#    'effectif': 131,
#    'chiffre_affaires_export': 21990,
#    'marge_brute': 55947064,
#    'excedent_brut_exploitation': 599607,
#    'resultat_exploitation': 665932,
#    'taux_croissance_chiffre_affaires': -7.6,
#    'taux_marge_brute': 101.2,
#    'taux_marge_EBITDA': 1.1,
#    'taux_marge_operationnelle': 1.2,
#    'BFR_exploitation': 3063399,
#    'BFR_hors_exploitation': 5755782,
#    'BFR': 8819181,
#    'BFR_exploitation_jours_CA': 20.2,
#    'BFR_hors_exploitation_jours_CA': 38,
#    'BFR_jours_CA': 58.2,
#    'delai_paiement_clients_jours': 91.5,
#    'delai_paiement_fournisseurs_jours': 86.4,
#    'ratio_stock_CA_jours': 0,
#    'capacite_autofinancement': 1098270,
#    'capacite_autofinancement_CA': 2,
#    'fonds_roulement_net_global': 8819178,
#    'couverture_BFR': 1,
#    'tresorerie': None,
#    'dettes_financieres': 319417,
#    'capacite_remboursement': 0.3,
#    'ratio_endettement': 0,
#    'autonomie_financiere': 37.5,
#    'taux_levier': 0.5,
#    'etat_dettes_1_an_au_plus': None,
#    'liquidite_generale': None,
#    'couverture_dettes': 7.4,
#    'fonds_propres': 10380135,
#    'marge_nette': 1.2,
#    'rentabilite_fonds_propres': 6.4,
#    'rentabilite_economique': 2.4,
#    'valeur_ajoutee': 9657357,
#    'valeur_ajoutee_CA': 17.5,
#    'salaires_charges_sociales': 8429229,
#    'salaires_CA': 15.2,
#    'impots_taxes': 533803},
#   {'annee': 2017,
#    'date_de_cloture_exercice': '2017-12-31',
#    'duree_exercice': 12,
#    'chiffre_affaires': 59875338,
#    'resultat': 2852645,
#    'effectif': 149,
#    'chiffre_affaires_export': 232979,
#    'marge_brute': 60895166,
#    'excedent_brut_exploitation': 5231784,
#    'resultat_exploitation': 5337735,
#    'taux_croissance_chiffre_affaires': 33.2,
#    'taux_marge_brute': 101.7,
#    'taux_marge_EBITDA': 8.7,
#    'taux_marge_operationnelle': 8.9,
#    'BFR_exploitation': 4939595,
#    'BFR_hors_exploitation': 1808227,
#    'BFR': 6747822,
#    'BFR_exploitation_jours_CA': 30.1,
#    'BFR_hors_exploitation_jours_CA': 11,
#    'BFR_jours_CA': 41.1,
#    'delai_paiement_clients_jours': 110.7,
#    'delai_paiement_fournisseurs_jours': 106.1,
#    'ratio_stock_CA_jours': 0,
#    'capacite_autofinancement': 3549260,
#    'capacite_autofinancement_CA': 5.9,
#    'fonds_roulement_net_global': 6930415,
#    'couverture_BFR': 1,
#    'tresorerie': 182592,
#    'dettes_financieres': 1470,
#    'capacite_remboursement': -0.1,
#    'ratio_endettement': 0,
#    'autonomie_financiere': 31.7,
#    'taux_levier': 0,
#    'etat_dettes_1_an_au_plus': None,
#    'liquidite_generale': None,
#    'couverture_dettes': -18.8,
#    'fonds_propres': 9717156,
#    'marge_nette': 4.8,
#    'rentabilite_fonds_propres': 29.4,
#    'rentabilite_economique': 9.3,
#    'valeur_ajoutee': 14235087,
#    'valeur_ajoutee_CA': 23.8,
#    'salaires_charges_sociales': 8226679,
#    'salaires_CA': 13.7,
#    'impots_taxes': 575729},
#   {'annee': 2016,
#    'date_de_cloture_exercice': '2016-12-31',
#    'duree_exercice': 12,
#    'chiffre_affaires': 44945845,
#    'resultat': 1980758,
#    'effectif': 129,
#    'chiffre_affaires_export': 218041,
#    'marge_brute': 45453363,
#    'excedent_brut_exploitation': 4649672,
#    'resultat_exploitation': 3958915,
#    'taux_croissance_chiffre_affaires': 46.6,
#    'taux_marge_brute': 101.1,
#    'taux_marge_EBITDA': 10.3,
#    'taux_marge_operationnelle': 8.8,
#    'BFR_exploitation': 5924109,
#    'BFR_hors_exploitation': -1852836,
#    'BFR': 4071273,
#    'BFR_exploitation_jours_CA': 48.1,
#    'BFR_hors_exploitation_jours_CA': -15,
#    'BFR_jours_CA': 33.1,
#    'delai_paiement_clients_jours': 127.1,
#    'delai_paiement_fournisseurs_jours': 113.9,
#    'ratio_stock_CA_jours': 0,
#    'capacite_autofinancement': 2831517,
#    'capacite_autofinancement_CA': 6.3,
#    'fonds_roulement_net_global': 4246170,
#    'couverture_BFR': 1,
#    'tresorerie': 174896,
#    'dettes_financieres': 1470,
#    'capacite_remboursement': -0.1,
#    'ratio_endettement': 0,
#    'autonomie_financiere': 27.2,
#    'taux_levier': 0,
#    'etat_dettes_1_an_au_plus': 5113025,
#    'liquidite_generale': 4.3,
#    'couverture_dettes': -19.9,
#    'fonds_propres': 6864510,
#    'marge_nette': 4.4,
#    'rentabilite_fonds_propres': 28.9,
#    'rentabilite_economique': 7.8,
#    'valeur_ajoutee': 13666309,
#    'valeur_ajoutee_CA': 30.4,
#    'salaires_charges_sociales': 8491900,
#    'salaires_CA': 18.9,
#    'impots_taxes': 516668},
#   {'annee': 2015,
#    'date_de_cloture_exercice': '2015-12-31',
#    'duree_exercice': 12,
#    'chiffre_affaires': 30660231,
#    'resultat': 1678387,
#    'effectif': 117,
#    'chiffre_affaires_export': None,
#    'marge_brute': 31381332,
#    'excedent_brut_exploitation': 2787461,
#    'resultat_exploitation': 2383576,
#    'taux_croissance_chiffre_affaires': None,
#    'taux_marge_brute': 102.4,
#    'taux_marge_EBITDA': 9.1,
#    'taux_marge_operationnelle': 7.8,
#    'BFR_exploitation': 4220358,
#    'BFR_hors_exploitation': -1308930,
#    'BFR': 2911428,
#    'BFR_exploitation_jours_CA': 50.2,
#    'BFR_hors_exploitation_jours_CA': -15.6,
#    'BFR_jours_CA': 34.6,
#    'delai_paiement_clients_jours': 103.5,
#    'delai_paiement_fournisseurs_jours': 78.4,
#    'ratio_stock_CA_jours': 0,
#    'capacite_autofinancement': 2308499,
#    'capacite_autofinancement_CA': 7.5,
#    'fonds_roulement_net_global': 2911428,
#    'couverture_BFR': 1,
#    'tresorerie': None,
#    'dettes_financieres': 622466,
#    'capacite_remboursement': 0.3,
#    'ratio_endettement': 0.1,
#    'autonomie_financiere': 30.3,
#    'taux_levier': 0.2,
#    'etat_dettes_1_an_au_plus': None,
#    'liquidite_generale': None,
#    'couverture_dettes': 5.3,
#    'fonds_propres': 4883752,
#    'marge_nette': 5.5,
#    'rentabilite_fonds_propres': 34.4,
#    'rentabilite_economique': 10.4,
#    'valeur_ajoutee': 9533480,
#    'valeur_ajoutee_CA': 31.1,
#    'salaires_charges_sociales': 6678953,
#    'salaires_CA': 21.8,
#    'impots_taxes': 450965}],
#  'representants': [{'qualite': 'Président',
#    'qualites': ['Président'],
#    'personne_morale': False,
#    'date_prise_de_poste': '2022-08-04',
#    'nom': 'VIROS',
#    'prenom': 'Alexander Paul Raymond',
#    'prenom_usuel': 'Alexander',
#    'nom_usage': None,
#    'nom_complet': 'Alexander Paul Raymond VIROS',
#    'sexe': 'M',
#    'date_de_naissance': '1978-01-08',
#    'date_de_naissance_formate': '08/01/1978',
#    'age': 45,
#    'nationalite': 'Française',
#    'code_nationalité': 'FR',
#    'code_nationalite': 'FR',
#    'ville_de_naissance': '72181 Le Mans (72)',
#    'pays_de_naissance': 'France',
#    'code_pays_de_naissance': 'FR',
#    'adresse_ligne_1': None,
#    'adresse_ligne_2': '7 Boulevard du Temple',
#    'adresse_ligne_3': None,
#    'code_postal': '75003',
#    'ville': 'Paris',
#    'pays': 'France',
#    'code_pays': 'FR'},
#   {'qualite': 'Commissaire aux comptes',
#    'qualites': ['Commissaire aux comptes'],
#    'personne_morale': True,
#    'date_prise_de_poste': '2022-08-04',
#    'denomination': 'ERNST & YOUNG et Autres',
#    'siren': '438476913',
#    'nom_complet': 'ERNST & YOUNG et Autres',
#    'forme_juridique': 'Société par actions simplifiée à capital variable',
#    'adresse_ligne_1': None,
#    'adresse_ligne_2': '1 et 2 Place Des Saisons',
#    'adresse_ligne_3': 'Paris la Défense 1',
#    'code_postal': '92400',
#    'ville': 'Courbevoie',
#    'pays': 'France',
#    'code_pays': 'FR'}],
#  'beneficiaires_effectifs': [{'date_greffe': '2022-08-04',
#    'type': 'BE_SOC',
#    'nom': 'VIROS',
#    'nom_usage': None,
#    'prenom': 'Alexander Paul Raymond',
#    'prenom_usuel': 'Alexander',
#    'pseudonyme': None,
#    'sexe': 'M',
#    'nationalite': 'Française',
#    'code_nationalite': 'FR',
#    'date_de_naissance_formatee': '01/1978',
#    'date_de_naissance_complete_formatee': '08/01/1978',
#    'ville_de_naissance': '72181 Le Mans (72)',
#    'pays_de_naissance': 'France',
#    'code_pays_de_naissance': 'FR',
#    'adresse_ligne_1': None,
#    'adresse_ligne_2': '7 Boulevard du Temple',
#    'adresse_ligne_3': None,
#    'code_postal': '75003',
#    'ville': 'Paris',
#    'pays': 'France',
#    'code_pays': 'FR',
#    'pourcentage_parts': None,
#    'pourcentage_parts_directes': None,
#    'pourcentage_parts_indirectes': None,
#    'pourcentage_parts_vocation_titulaire': None,
#    'details_parts_directes': None,
#    'details_parts_indirectes': None,
#    'details_parts_vocation_titulaire': None,
#    'pourcentage_votes': None,
#    'pourcentage_votes_directs': None,
#    'pourcentage_votes_indirect': None,
#    'details_votes_directs': None,
#    'details_votes_indirects': None,
#    'details_societe_de_gestion': None,
#    'detention_pouvoir_decision_ag': False,
#    'detention_pouvoir_nom_membre_conseil_administration': False,
#    'detention_autres_moyens_controle': False,
#    'beneficiaire_representant_legal': True,
#    'representant_legal_placement_sans_gestion_delegation': False}],
#  'depots_actes': [{'date_depot': '2023-02-23',
#    'date_depot_formate': '23/02/2023',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 23-02-2023.pdf',
#    'token': 'QWduSlB1THJhOVRlN19DMDAyMkExMDAxTDIxMzE5N0QyMDIzMDIyOEgxNzUyMjVUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': "Modification relative aux dirigeants d'une société",
#      'date_acte': '2023-01-13',
#      'date_acte_formate': '13/01/2023'}]},
#   {'date_depot': '2022-08-09',
#    'date_depot_formate': '09/08/2022',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 09-08-2022.pdf',
#    'token': 'QWJGb0UzN3BvSzlLcl9DMDAyMkExMDAxTDIxOTI5NkQyMDIyMDgxNkgxNjU0MzdUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale ordinaire",
#      'decision': 'Modification des commissaires aux comptes',
#      'date_acte': '2022-06-30',
#      'date_acte_formate': '30/06/2022'}]},
#   {'date_depot': '2021-10-04',
#    'date_depot_formate': '04/10/2021',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 04-10-2021.pdf',
#    'token': 'QVc0c1V2ZlZxTExJVF9DMDAyMkExMDAxTDM2Mzk4NkQyMDIxMTAwOUgxNzM4NTlUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': "Modification relative aux dirigeants d'une société",
#      'date_acte': '2021-08-31',
#      'date_acte_formate': '31/08/2021'}]},
#   {'date_depot': '2021-06-29',
#    'date_depot_formate': '29/06/2021',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 29-06-2021.pdf',
#    'token': 'QVpFaEI1S2gyMXo2OF9DMDAyMkExMDAxTDQ0NTUyMEQyMDIxMDcwNkgxOTI4NTNUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale extraordinaire",
#      'decision': "Modification relative aux dirigeants d'une société Modification de la forme juridique ou du statut particulier",
#      'date_acte': '2021-05-28',
#      'date_acte_formate': '28/05/2021'},
#     {'type': 'Rapport du commissaire à la transformation',
#      'decision': "Modification relative aux dirigeants d'une société Modification de la forme juridique ou du statut particulier",
#      'date_acte': '2021-05-12',
#      'date_acte_formate': '12/05/2021'},
#     {'type': 'Statuts mis à jour',
#      'decision': "Modification relative aux dirigeants d'une société Modification de la forme juridique ou du statut particulier",
#      'date_acte': '2021-05-28',
#      'date_acte_formate': '28/05/2021'}]},
#   {'date_depot': '2021-04-08',
#    'date_depot_formate': '08/04/2021',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 08-04-2021.pdf',
#    'token': 'QU9sMDNuVnM3QkVMTV9DMDAyMkExMDAxTDAyMjE4M0QyMDIxMDUwN0gxNzEyMjRUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale extraordinaire",
#      'decision': 'Modification des principales activités',
#      'date_acte': '2021-01-21',
#      'date_acte_formate': '21/01/2021'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Modification des principales activités',
#      'date_acte': '2021-01-21',
#      'date_acte_formate': '21/01/2021'}]},
#   {'date_depot': '2021-04-08',
#    'date_depot_formate': '08/04/2021',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 08-04-2021.pdf',
#    'token': 'QVlNaE9xR0FLZ3NReF9DMDAyMkExMDAxTDI5MTM4N0QyMDIxMDQxM0gxODIxMzJUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale extraordinaire",
#      'decision': 'Modification des principales activités',
#      'date_acte': '2021-01-21',
#      'date_acte_formate': '21/01/2021'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Modification des principales activités',
#      'date_acte': '2021-01-21',
#      'date_acte_formate': '21/01/2021'}]},
#   {'date_depot': '2021-04-07',
#    'date_depot_formate': '07/04/2021',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-04-2021.pdf',
#    'token': 'QU8xaHk4dEtFNUFDTV9DMDAyMkExMDAxTDI5MTA2NUQyMDIxMDQxM0gxODA1MDdUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale ordinaire",
#      'decision': "Modification relative aux dirigeants d'une société",
#      'date_acte': '2021-03-01',
#      'date_acte_formate': '01/03/2021'}]},
#   {'date_depot': '2020-11-18',
#    'date_depot_formate': '18/11/2020',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 18-11-2020.pdf',
#    'token': 'QWtNdHpQTTlmb1dLQl9DMDAyMkExMDAxTDAyNjUzN0QyMDIwMTEyNUgwMTM1NDRUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale ordinaire",
#      'decision': "Modification relative aux dirigeants d'une société",
#      'date_acte': '2020-10-05',
#      'date_acte_formate': '05/10/2020'}]},
#   {'date_depot': '2019-05-09',
#    'date_depot_formate': '09/05/2019',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 09-05-2019.pdf',
#    'token': 'QUhOMWRVR29zR21wNl9DMDAyMkExMDAxTDAxNjIzMkQyMDE5MDUxNUgwMTI1NDJUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale extraordinaire",
#      'decision': 'Modification des principales activités',
#      'date_acte': '2019-04-23',
#      'date_acte_formate': '23/04/2019'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Modification des principales activités',
#      'date_acte': '2019-04-23',
#      'date_acte_formate': '23/04/2019'}]},
#   {'date_depot': '2016-12-15',
#    'date_depot_formate': '15/12/2016',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 15-12-2016.pdf',
#    'token': 'QUhZRmVjdFFQNUNoZ19DMDAyMkExMDAxTDM3Nzg4OUQyMDE2MTIyN0gyMDE5MjBUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': 'Transfert siège social et établissement principal Modification des principales activités',
#      'date_acte': '2016-11-14',
#      'date_acte_formate': '14/11/2016'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Transfert siège social et établissement principal Modification des principales activités',
#      'date_acte': '2016-12-01',
#      'date_acte_formate': '01/12/2016'}]},
#   {'date_depot': '2015-12-23',
#    'date_depot_formate': '23/12/2015',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 23-12-2015.pdf',
#    'token': 'QXBDeURncXlqUVFGb19DMDAyMkExMDAxTDcwMjk1NUQyMDE2MDEwNUgxODIxMTFUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale extraordinaire",
#      'decision': 'Modification des statuts',
#      'date_acte': '2015-12-18',
#      'date_acte_formate': '18/12/2015'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Modification des statuts',
#      'date_acte': '2015-12-18',
#      'date_acte_formate': '18/12/2015'}]},
#   {'date_depot': '2015-11-23',
#    'date_depot_formate': '23/11/2015',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 23-11-2015.pdf',
#    'token': 'QUdTZXE0UDJMaDk1MF9DMDAyMkExMDAxTDQyODQ4NUQyMDE1MTIwNUgxNjUwMjlUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': 'Modification de la dénomination de la personne morale',
#      'date_acte': '2015-11-02',
#      'date_acte_formate': '02/11/2015'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Modification de la dénomination de la personne morale',
#      'date_acte': '2015-11-02',
#      'date_acte_formate': '02/11/2015'}]},
#   {'date_depot': '2015-09-24',
#    'date_depot_formate': '24/09/2015',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 24-09-2015.pdf',
#    'token': 'QU00dmVJcXI2anlTYl9DMDAyMkExMDAxTDc4NDk5OEQyMDE1MTAwNkgxNzQwMjlUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': "Modification relative aux dirigeants d'une société",
#      'date_acte': '2015-09-01',
#      'date_acte_formate': '01/09/2015'}]},
#   {'date_depot': '2014-01-22',
#    'date_depot_formate': '22/01/2014',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 22-01-2014.pdf',
#    'token': 'QUlQYmFSbVdablpWRF9DMDAyMkExMDAxTDAwMzEwM0QyMDE0MDIwM0gxMDQ2MjZUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale extraordinaire",
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2012-03-07',
#    'date_depot_formate': '07/03/2012',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-03-2012.pdf',
#    'token': 'QTN3WkVzYnJkR2VGSF9SQUNUMl8zNDMwMDk4NjZfNjkwMV8xOTg3QjAyNjE5XzIwMTJfNjU5NTE',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2012-03-07',
#    'date_depot_formate': '07/03/2012',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-03-2012.pdf',
#    'token': 'QUpWdGlWUEs4ZjZyWl9SQUNUMl8zNDMwMDk4NjZfNjkwMV8xOTg3QjAyNjE5XzIwMTJfNjU5NTI',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2011-09-07',
#    'date_depot_formate': '07/09/2011',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-09-2011.pdf',
#    'token': 'QWFtTjJSOWlXVEtLTV9SQUNUMl8zNDMwMDk4NjZfNjkwMV8xOTg3QjAyNjE5XzIwMTFfMjA5NDMx',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': "Extrait de procès-verbal d'assemblée générale mixte",
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Liste des sièges sociaux antérieurs',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2011-09-07',
#    'date_depot_formate': '07/09/2011',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-09-2011.pdf',
#    'token': 'QWF4RWVCemgxQlh1Rl9SQUNUMl8zNDMwMDk4NjZfNjkwMV8xOTg3QjAyNjE5XzIwMTFfMjA5NDMz',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': "Extrait de procès-verbal d'assemblée générale mixte",
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Liste des sièges sociaux antérieurs',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2011-09-07',
#    'date_depot_formate': '07/09/2011',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-09-2011.pdf',
#    'token': 'QWNidnZ4RHJscjZ0UV9SQUNUMl8zNDMwMDk4NjZfNjkwMV8xOTg3QjAyNjE5XzIwMTFfMjA5NDMy',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': "Extrait de procès-verbal d'assemblée générale mixte",
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Liste des sièges sociaux antérieurs',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2011-09-07',
#    'date_depot_formate': '07/09/2011',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-09-2011.pdf',
#    'token': 'QXpMTmFXM3RoWlNUWV9SQUNUMl8zNDMwMDk4NjZfNjkwMV8xOTg3QjAyNjE5XzIwMTFfMjA5NDM0',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': "Extrait de procès-verbal d'assemblée générale mixte",
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Liste des sièges sociaux antérieurs',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2011-03-07',
#    'date_depot_formate': '07/03/2011',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-03-2011.pdf',
#    'token': 'QXR1UlE4b3lPOWFlaF9SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTFfMjE4NTgwMw',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2011-03-07',
#    'date_depot_formate': '07/03/2011',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-03-2011.pdf',
#    'token': 'QXB5TmhEc3lXUWFLQ19SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTFfMjE4NTgwMQ',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2011-03-07',
#    'date_depot_formate': '07/03/2011',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-03-2011.pdf',
#    'token': 'QWJKdklMV3pmQzNCTl9SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTFfMjE4NTgwMg',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2010-12-30',
#    'date_depot_formate': '30/12/2010',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 30-12-2010.pdf',
#    'token': 'QVd5aWdLVlliMVF0al9SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTBfMTE2OTk3MDE',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2010-12-30',
#    'date_depot_formate': '30/12/2010',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 30-12-2010.pdf',
#    'token': 'QXdxMVIzQ0ZTdDdFNF9SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTBfMTE2OTk5MDE',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2010-11-25',
#    'date_depot_formate': '25/11/2010',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 25-11-2010.pdf',
#    'token': 'QTRBTUNxV2xsNXdpU19SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTBfMTA0NTYyMDE',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2010-08-12',
#    'date_depot_formate': '12/08/2010',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 12-08-2010.pdf',
#    'token': 'QUVkWFBRV2JFYkN6Ml9SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTBfNzA2MTYwMg',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2010-08-12',
#    'date_depot_formate': '12/08/2010',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 12-08-2010.pdf',
#    'token': 'QUNGQ1pERnFHRmpqQl9SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTBfNzA2MTYwMQ',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2010-02-25',
#    'date_depot_formate': '25/02/2010',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 25-02-2010.pdf',
#    'token': 'QTVoTEx2eU85QWp0SV9SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTBfMTg0MzAwMQ',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2009-02-02',
#    'date_depot_formate': '02/02/2009',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 02-02-2009.pdf',
#    'token': 'QWszUG5TVmNvcnJoVV9SQUNUMDkwMTMzMTgzOQ',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2008-01-28',
#    'date_depot_formate': '28/01/2008',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 28-01-2008.pdf',
#    'token': 'QW1TRlgxVGFJNkJhMV9SQUNUMDgwMTAyMjkxNQ',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2007-04-19',
#    'date_depot_formate': '19/04/2007',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 19-04-2007.pdf',
#    'token': 'QWRMVnJzMzhVYXQ1RV9SQUNUMDcwMDA4MTg1NA',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2006-08-03',
#    'date_depot_formate': '03/08/2006',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 03-08-2006.pdf',
#    'token': 'QU5QN1Z3V1VqY3haWV9SQUNUMDYwMDY0NDc3MA',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2006-01-02',
#    'date_depot_formate': '02/01/2006',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 02-01-2006.pdf',
#    'token': 'QW5nVDYzTEdjMjZjWl9SQUNUMDYwMDE4MzUwMQ',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2005-12-09',
#    'date_depot_formate': '09/12/2005',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 09-12-2005.pdf',
#    'token': 'QU5aU1VUU2RmWjVtZV9SQUNUMDUwMDc2MzgyNg',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2005-10-06',
#    'date_depot_formate': '06/10/2005',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 06-10-2005.pdf',
#    'token': 'QVVDVzFmbVdHSlJFSl9SQUNUMDUwMTE0ODk5NQ',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2005-10-06',
#    'date_depot_formate': '06/10/2005',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 06-10-2005.pdf',
#    'token': 'QWxlVVNraGJpN2FOU19SQUNUMDUwMTE0ODk5NA',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2005-01-04',
#    'date_depot_formate': '04/01/2005',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 04-01-2005.pdf',
#    'token': 'QXgxZXVPWkxQSTJ2Z19SQUNUMDUwMDAwMjQ2Mg',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2004-08-10',
#    'date_depot_formate': '10/08/2004',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 10-08-2004.pdf',
#    'token': 'QUtKWlFrUTlsMlhaaV9SQUNUMDQwMDQ2MTMzOQ',
#    'actes': [{'type': "Procès-verbal d'assemblée générale",
#      'decision': 'Reconstitution des capitaux propres',
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2003-10-02',
#    'date_depot_formate': '02/10/2003',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 02-10-2003.pdf',
#    'token': 'QUM2Slh0aVBnM1B2el9SQUNUMDMwMDkxMzM1Ng',
#    'actes': [{'type': "Procès-verbal d'assemblée générale mixte",
#      'decision': "Continuation de la société malgré les pertes Modification relative aux dirigeants d'une société",
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2002-10-29',
#    'date_depot_formate': '29/10/2002',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 29-10-2002.pdf',
#    'token': 'QVQ5akYzazBQbWlXVl9SQUNUMDIwMTEwNzgzNQ',
#    'actes': [{'type': "Procès-verbal d'assemblée générale ordinaire",
#      'decision': "Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2001-12-07',
#    'date_depot_formate': '07/12/2001',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-12-2001.pdf',
#    'token': 'QU1QRlRrZFk3QUhVcF9SQUNUMDIwMDUyNTg2NQ',
#    'actes': [{'type': "Procès-verbal d'assemblée générale extraordinaire",
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Rapport du commissaire aux comptes',
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2001-04-26',
#    'date_depot_formate': '26/04/2001',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 26-04-2001.pdf',
#    'token': 'QWRNcTllelBISlVFeV9SQUNUMDEwMDM0MDk1NQ',
#    'actes': [{'type': "Procès-verbal d'assemblée générale extraordinaire",
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2000-08-08',
#    'date_depot_formate': '08/08/2000',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 08-08-2000.pdf',
#    'token': 'QW9NMUNGbGtBUGw2RF9SQUNUMDAwMDA0MTY1NA',
#    'actes': [{'type': 'Acte',
#      'decision': 'Continuation de la société malgré les pertes',
#      'date_acte': '2000-08-08',
#      'date_acte_formate': '08/08/2000'}]},
#   {'date_depot': '1999-12-15',
#    'date_depot_formate': '15/12/1999',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 15-12-1999.pdf',
#    'token': 'QUlFN0xKcTZCd3hubF9SQUNUMDAwMDM2MzM1MQ',
#    'actes': [{'type': 'Acte',
#      'decision': 'fusion absorption',
#      'date_acte': '1999-12-15',
#      'date_acte_formate': '15/12/1999'},
#     {'type': 'Déclaration de conformité',
#      'decision': 'fusion absorption',
#      'date_acte': '1999-12-15',
#      'date_acte_formate': '15/12/1999'}]},
#   {'date_depot': '1999-03-25',
#    'date_depot_formate': '25/03/1999',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 25-03-1999.pdf',
#    'token': 'QTJIMFVLdUdkVDNDRl9SQUNUOTkwMDIwMzEyMw',
#    'actes': [{'type': 'Acte',
#      'decision': 'Modification des dirigeants, organes de contrôle',
#      'date_acte': '1999-03-25',
#      'date_acte_formate': '25/03/1999'}]},
#   {'date_depot': '1998-11-20',
#    'date_depot_formate': '20/11/1998',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 20-11-1998.pdf',
#    'token': 'QXVBMEFGWjdESkx4dF9SQUNUOTgwMDY1NDg3Mg',
#    'actes': [{'type': 'Acte',
#      'decision': 'Modification dénomination - objet social',
#      'date_acte': '1998-11-20',
#      'date_acte_formate': '20/11/1998'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Modification dénomination - objet social',
#      'date_acte': '1998-11-20',
#      'date_acte_formate': '20/11/1998'}]},
#   {'date_depot': '1998-07-29',
#    'date_depot_formate': '29/07/1998',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 29-07-1998.pdf',
#    'token': 'QWZMV1lWSVN3VUNINl9SQUNUOTgwMDYxNTUwNA',
#    'actes': [{'type': 'Rapport du commissaire aux apports',
#      'decision': 'Rapport commissaire aux apports',
#      'date_acte': '1998-07-29',
#      'date_acte_formate': '29/07/1998'}]},
#   {'date_depot': '1998-07-24',
#    'date_depot_formate': '24/07/1998',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 24-07-1998.pdf',
#    'token': 'QWZkRGFSclptaU9rYl9SQUNUOTgwMDQyNjg3Mg',
#    'actes': [{'type': 'Projet',
#      'decision': 'fusion absorption',
#      'date_acte': '1998-07-24',
#      'date_acte_formate': '24/07/1998'}]},
#   {'date_depot': '1998-06-30',
#    'date_depot_formate': '30/06/1998',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 30-06-1998.pdf',
#    'token': 'QThSMktKS2p4ZjJVbl9SQUNUOTgwMDQ3NTMxMg',
#    'actes': [{'type': 'Acte',
#      'decision': 'Modification des dirigeants, organes de contrôle',
#      'date_acte': '1998-06-30',
#      'date_acte_formate': '30/06/1998'}]},
#   {'date_depot': '1998-06-24',
#    'date_depot_formate': '24/06/1998',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 24-06-1998.pdf',
#    'token': 'QU40RGx6aVZwc1hHWF9SQUNUOTgwMDExODkyOQ',
#    'actes': [{'type': 'Ordonnance du président',
#      'decision': 'Nomination de commissaire aux apports',
#      'date_acte': '1998-06-24',
#      'date_acte_formate': '24/06/1998'}]},
#   {'date_depot': '1997-06-26',
#    'date_depot_formate': '26/06/1997',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 26-06-1997.pdf',
#    'token': 'QXJZMXo0NXRnSVIxcF9SQUNUOTcwMDM2NDgzMQ',
#    'actes': [{'type': 'Acte',
#      'decision': 'Transfert du siège social de la personne morale',
#      'date_acte': '1997-06-26',
#      'date_acte_formate': '26/06/1997'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Transfert du siège social de la personne morale',
#      'date_acte': '1997-06-26',
#      'date_acte_formate': '26/06/1997'}]},
#   {'date_depot': '1996-10-14',
#    'date_depot_formate': '14/10/1996',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 14-10-1996.pdf',
#    'token': 'QUtJZHdoVDVGdFdadF9SQUNUOTYwMDU4MTEwNQ',
#    'actes': [{'type': 'Acte',
#      'decision': 'fusion absorption Décision sur la modification du capital social',
#      'date_acte': '1996-10-14',
#      'date_acte_formate': '14/10/1996'},
#     {'type': 'Déclaration de conformité',
#      'decision': 'fusion absorption Décision sur la modification du capital social',
#      'date_acte': '1996-10-14',
#      'date_acte_formate': '14/10/1996'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'fusion absorption Décision sur la modification du capital social',
#      'date_acte': '1996-10-14',
#      'date_acte_formate': '14/10/1996'}]},
#   {'date_depot': '1996-08-22',
#    'date_depot_formate': '22/08/1996',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 22-08-1996.pdf',
#    'token': 'QVBtVUVzWFdDN2luQl9SQUNUOTYwMDUwOTczMQ',
#    'actes': [{'type': 'Acte',
#      'decision': 'Rapport commissaire aux apports',
#      'date_acte': '1996-08-22',
#      'date_acte_formate': '22/08/1996'},
#     {'type': 'Rapport du commissaire à la fusion',
#      'decision': 'Rapport commissaire aux apports',
#      'date_acte': '1996-08-22',
#      'date_acte_formate': '22/08/1996'}]},
#   {'date_depot': '1996-07-31',
#    'date_depot_formate': '31/07/1996',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 31-07-1996.pdf',
#    'token': 'QWZTSDJ2aG9nYzRvbl9SQUNUOTYwMDQ3MzY4OA',
#    'actes': [{'type': 'Projet',
#      'decision': 'fusion absorption',
#      'date_acte': '1996-07-31',
#      'date_acte_formate': '31/07/1996'}]},
#   {'date_depot': '1996-07-09',
#    'date_depot_formate': '09/07/1996',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 09-07-1996.pdf',
#    'token': 'QU1paVk3THViVTFjcV9SQUNUOTYwMDM4ODg0OA',
#    'actes': [{'type': 'Ordonnance du président',
#      'decision': 'Nomination de commissaire à la fusion',
#      'date_acte': '1996-07-09',
#      'date_acte_formate': '09/07/1996'}]},
#   {'date_depot': '1995-06-30',
#    'date_depot_formate': '30/06/1995',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 30-06-1995.pdf',
#    'token': 'QWdJMDVpOW42S0lra19SQUNUOTUwMDQ1NTA5OQ',
#    'actes': [{'type': 'Acte',
#      'decision': 'Modification des statuts',
#      'date_acte': '1995-06-30',
#      'date_acte_formate': '30/06/1995'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Modification des statuts',
#      'date_acte': '1995-06-30',
#      'date_acte_formate': '30/06/1995'}]},
#   {'date_depot': '1994-06-24',
#    'date_depot_formate': '24/06/1994',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 24-06-1994.pdf',
#    'token': 'QW83NFduMnZTT2d0ZV9SQUNUOTQwMDMyNTgwMA',
#    'actes': [{'type': 'Acte',
# ...
#    'greffe': 'Lyon',
#    'nom_entreprise': 'Adecco Formation',
#    'personne_morale': True,
#    'sigle': None,
#    'denomination': 'Adecco Formation',
#    'nom_commercial': None,
#    'forme_juridique': 'Société à Responsabilité Limitée',
#    'nom': None,
#    'prenom': None,
#    'administration': "DAVY François nom d'usage : DAVY n'est plus gérant. DEHAZE Alain nom d'usage : DEHAZE devient gérant.",
#    'pseudonyme': None,
#    'nationnalite': None,
#    'adresse': '19 rue Louis Guérin 69100 Villeurbanne',
#    'capital': None,
#    'devise_capital': None,
#    'activite': "Assurer soit directement, soit indirectement la formation et le perfectionnement du personnel des entreprises dans le cadre de la Loi 71.575 du 16/7/1971 et de ses décrets d'application dans toutes activités",
#    'date_debut_activite': None,
#    'description': "Nouveau siège. Modification de l'activité. Modification de l'administration."},
#   {'numero_parution': '20110065',
#    'date': '2011-09-26',
#    'numero_annonce': '7902',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'type': 'Dépôt des comptes',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'sigle': None,
#    'denomination': 'Adecco Formation',
#    'forme_juridique': 'Société à responsabilité limitée',
#    'adresse': '5 rue de Milan 75009 Paris',
#    'date_cloture': '2010-12-31',
#    'type_depot': 'Comptes annuels et rapports',
#    'descriptif': None},
#   {'numero_parution': '20110075',
#    'date': '2011-04-15',
#    'numero_annonce': '1420',
#    'annonce_rectificative': False,
#    'bodacc': 'B',
#    'type': 'Modification',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'nom_entreprise': 'Adecco Formation',
#    'personne_morale': True,
#    'sigle': None,
#    'denomination': 'Adecco Formation',
#    'nom_commercial': None,
#    'forme_juridique': 'Société à responsabilité limitée',
#    'nom': None,
#    'prenom': None,
#    'administration': None,
#    'pseudonyme': None,
#    'nationnalite': None,
#    'adresse': '5 rue de Milan 75009 Paris',
#    'capital': 1466700,
#    'devise_capital': 'EUR',
#    'activite': "Assurer, soit directement, soit indirectement la formation et Leperfectionnement du personnel des entreprises dans le cadre de la loi du 16/07/1991 et décrets d'application dans toutes activités",
#    'date_debut_activite': None,
#    'description': "modification survenue sur l'origine du fonds d'un établissement principal"},
#   {'numero_parution': '20110057',
#    'date': '2011-03-22',
#    'numero_annonce': '890',
#    'annonce_rectificative': False,
#    'bodacc': 'B',
#    'type': 'Modification',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'nom_entreprise': 'Adecco Formation',
#    'personne_morale': True,
#    'sigle': None,
#    'denomination': 'Adecco Formation',
#    'nom_commercial': None,
#    'forme_juridique': 'Société à responsabilité limitée',
#    'nom': None,
#    'prenom': None,
#    'administration': None,
#    'pseudonyme': None,
#    'nationnalite': None,
#    'adresse': '5 rue de Milan 75009 Paris',
#    'capital': 1466700,
#    'devise_capital': 'EUR',
#    'activite': None,
#    'date_debut_activite': None,
#    'description': 'modification survenue sur le capital (augmentation)'},
#   {'numero_parution': '20100252',
#    'date': '2010-12-29',
#    'numero_annonce': '1077',
#    'annonce_rectificative': False,
#    'bodacc': 'A',
#    'type': 'Vente',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'nom_entreprise': 'Adecco Formation',
#    'personne_morale': True,
#    'sigle': None,
#    'denomination': 'Adecco Formation',
#    'nom_commercial': None,
#    'forme_juridique': 'Société à Responsabilité Limitée',
#    'nom': None,
#    'prenom': None,
#    'administration': None,
#    'pseudonyme': None,
#    'nationnalite': None,
#    'adresse': '5 rue de Milan 75009 Paris',
#    'capital': None,
#    'devise_capital': None,
#    'activite': "Partie d'activité concernée : Formation",
#    'date_immatriculation': None,
#    'categorie_vente': 'Autre achat, apport, attribution',
#    'date_debut_activite': '2010-01-01',
#    'origine_fonds': "Nouvelle branche d'activité. Fonds acquis par achat au prix stipulé de 140408.87 EUR",
#    'commentaires': "Achat d'une branche d'activité sis 2 Boulevard du 11 Novembre 1918 69100 Villeurbanne pour être exploité 19 rue Louis Guérin 69100 Villeurbanne",
#    'oppositions': 'Pour la correspondance : Adecco Formation, 5 rue de Milan 75009 Paris; pour la validité : Adecco Formation 19 rue Louis Guérin 69100 Villeurbanne',
#    'declaration_creance': None,
#    'publication_legale': 'Tout Lyon, le 11/12/2010',
#    'denomination_ancien_proprietaire': 'AJILON Sales & Marketing',
#    'siren_ancien_proprietaire': '304970031'},
#   {'numero_parution': '20100061',
#    'date': '2010-09-14',
#    'numero_annonce': '6005',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'type': 'Dépôt des comptes',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'sigle': None,
#    'denomination': 'NOVITEC LE MONDE DE LA FORMATION',
#    'forme_juridique': 'Société à responsabilité limitée',
#    'adresse': '5 R DE MILAN 75009 PARIS',
#    'date_cloture': '2009-12-31',
#    'type_depot': 'Comptes annuels et rapports',
#    'descriptif': None},
#   {'numero_parution': '20100167',
#    'date': '2010-08-29',
#    'numero_annonce': '1044',
#    'annonce_rectificative': False,
#    'bodacc': 'B',
#    'type': 'Modification',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'nom_entreprise': 'Adecco Formation',
#    'personne_morale': True,
#    'sigle': None,
#    'denomination': 'Adecco Formation',
#    'nom_commercial': None,
#    'forme_juridique': 'Société à responsabilité limitée',
#    'nom': None,
#    'prenom': None,
#    'administration': 'Commissaire aux comptes titulaire partant : CABINET ORFIS, Commissaire aux comptes suppléant partant : Marcon, Pierre, Commissaire aux comptes suppléant partant : Guenne, Philippe, nomination du Commissaire aux comptes suppléant : AUDITEX',
#    'pseudonyme': None,
#    'nationnalite': None,
#    'adresse': '5 rue de Milan 75009 Paris',
#    'capital': 1464990,
#    'devise_capital': 'EUR',
#    'activite': None,
#    'date_debut_activite': None,
#    'description': "modification survenue sur la dénomination et l'administration"},
#   {'numero_parution': '20100053',
#    'date': '2010-03-17',
#    'numero_annonce': '1279',
#    'annonce_rectificative': False,
#    'bodacc': 'B',
#    'type': 'Modification',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'nom_entreprise': 'NOVITEC LE MONDE DE LA FORMATION',
#    'personne_morale': True,
#    'sigle': None,
#    'denomination': 'NOVITEC LE MONDE DE LA FORMATION',
#    'nom_commercial': None,
#    'forme_juridique': 'Société à responsabilité limitée',
#    'nom': None,
#    'prenom': None,
#    'administration': "Gérant partant : Levy, nom d'usage : Levy-Waitz, Patrick, nomination du Gérant : Davy, Francois",
#    'pseudonyme': None,
#    'nationnalite': None,
#    'adresse': '5 rue de Milan 75009 Paris',
#    'capital': 1464990,
#    'devise_capital': 'EUR',
#    'activite': None,
#    'date_debut_activite': None,
#    'description': "modification survenue sur l'administration"},
#   {'numero_parution': '20090092',
#    'date': '2009-12-09',
#    'numero_annonce': '7026',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'type': 'Dépôt des comptes',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'sigle': None,
#    'denomination': 'NOVITEC LE MONDE DE LA FORMATION',
#    'forme_juridique': 'Société à responsabilité limitée',
#    'adresse': '5 rue de Milan 75009 Paris',
#    'date_cloture': '2008-12-31',
#    'type_depot': 'Comptes annuels et rapports',
#    'descriptif': None},
#   {'numero_parution': '20090036',
#    'date': '2009-02-20',
#    'numero_annonce': '3179',
#    'annonce_rectificative': False,
#    'bodacc': 'B',
#    'type': 'Modification',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'nom_entreprise': 'NOVITEC LE MONDE DE LA FORMATION',
#    'personne_morale': True,
#    'sigle': None,
#    'denomination': 'NOVITEC LE MONDE DE LA FORMATION',
#    'nom_commercial': None,
#    'forme_juridique': 'Société à responsabilité limitée',
#    'nom': None,
#    'prenom': None,
#    'administration': None,
#    'pseudonyme': None,
#    'nationnalite': None,
#    'adresse': '5 rue de Milan 75009 Paris',
#    'capital': 1464990,
#    'devise_capital': 'EUR',
#    'activite': None,
#    'date_debut_activite': None,
#    'description': 'modification survenue sur le capital (augmentation)'},
#   {'numero_parution': '20080073',
#    'date': '2008-09-26',
#    'numero_annonce': '1223',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'type': 'Dépôt des comptes',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'sigle': None,
#    'denomination': 'NOVITEC LE MONDE DE LA FORMATION',
#    'forme_juridique': 'Société à responsabilité limitée',
#    'adresse': '5 rue de Milan 75009 Paris',
#    'date_cloture': '2007-12-31',
#    'type_depot': 'Comptes annuels et rapports',
#    'descriptif': None},
#   {'numero_parution': '20080089',
#    'date': '2008-05-27',
#    'numero_annonce': '1121',
#    'annonce_rectificative': False,
#    'bodacc': 'B',
#    'type': 'Modification',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'nom_entreprise': 'NOVITEC LE MONDE DE LA FORMATION',
#    'personne_morale': True,
#    'sigle': None,
#    'denomination': 'NOVITEC LE MONDE DE LA FORMATION',
#    'nom_commercial': None,
#    'forme_juridique': 'Société à responsabilité limitée',
#    'nom': None,
#    'prenom': None,
#    'administration': None,
#    'pseudonyme': None,
#    'nationnalite': None,
#    'adresse': '5 rue de Milan 75009 Paris',
#    'capital': 465000,
#    'devise_capital': 'EUR',
#    'activite': None,
#    'date_debut_activite': None,
#    'description': "modification survenue sur l'adresse du siège"}],
#  'publications_shal': [{'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ['Mouvement des Commissaires aux comptes'],
#    'date_parution': '2022-07-30',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Essor Rhône',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ['Mouvement des Dirigeants'],
#    'date_parution': '2021-09-30',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tribune de Lyon',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ['Modification de la Forme juridique',
#     'Mouvement des Dirigeants'],
#    'date_parution': '2021-06-12',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Essor Rhône',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ["Mouvement sur l'activité ou l'Objet social"],
#    'date_parution': '2021-04-03',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Essor Rhône',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ['Mouvement des Dirigeants'],
#    'date_parution': '2021-03-27',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Essor Rhône',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ['Rectificatif / Erratum'],
#    'date_parution': '2020-11-07',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Essor Rhône',
#    'types': ['Annonces diverses']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ['Mouvement des Dirigeants'],
#    'date_parution': '2020-10-24',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Essor Rhône',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ["Mouvement sur l'activité ou l'Objet social"],
#    'date_parution': '2019-05-09',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tribune de Lyon',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ["Modification de l'adresse du Siège social"],
#    'date_parution': '2016-11-24',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tribune de Lyon',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ["Mouvement sur l'activité ou l'Objet social"],
#    'date_parution': '2015-12-26',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Affiches',
#    'types': ['Modification']},
#   {'nom_entreprise': 'Adecco Training',
#    'departement': '69',
#    'evenements': ['Modification de la dénomination'],
#    'date_parution': '2015-11-14',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Affiches',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO FORMATION',
#    'departement': '69',
#    'evenements': ['Mouvement des Dirigeants'],
#    'date_parution': '2015-09-05',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Affiches',
#    'types': ['Modification']},
#   {'nom_entreprise': 'Adecco Formation',
#    'departement': '69',
#    'evenements': ['Réduction de capital social'],
#    'date_parution': '2014-01-04',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Affiches',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO FORMATION',
#    'departement': '69',
#    'evenements': ['Modification du Capital social'],
#    'date_parution': '2012-02-25',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon (Le)',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO FORMATION',
#    'departement': '69',
#    'evenements': ["Modification de l'adresse du Siège social",
#     'Mouvement des Dirigeants'],
#    'date_parution': '2011-07-23',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon (Le)',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO FORMATION',
#    'departement': '69',
#    'evenements': ["Modification de l'adresse du Siège social"],
#    'date_parution': '2011-07-16',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Affiches parisiennes (Les)',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO FORMATION',
#    'departement': '75',
#    'evenements': ['Modification de la dénomination',
#     'Mouvement des Dirigeants'],
#    'date_parution': '2010-06-08',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Petites Affiches (Les) - La Loi - Le Quotidien Juridique - Gazette du Palais',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO FORMATION',
#    'departement': '75',
#    'evenements': ['Modification de la dénomination'],
#    'date_parution': '2010-06-08',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Petites Affiches (Les) - La Loi - Le Quotidien Juridique - Gazette du Palais',
#    'types': ['Modification']},
#   {'nom_entreprise': 'NOVITEC LE MONDE DE LA FORMATION',
#    'departement': '75',
#    'evenements': ['Mouvement des Dirigeants'],
#    'date_parution': '2010-01-19',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Petites Affiches (Les) - La Loi - Le Quotidien Juridique - Gazette du Palais',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ['Mouvement des Dirigeants'],
#    'date_parution': '2023-02-22',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Ouest France WEB',
#    'types': ['Modification']}],
#  'procedures_collectives': [],
#  'procedure_collective_existe': False,
#  'procedure_collective_en_cours': False,
#  'derniers_statuts': {'date_depot': '2021-06-29',
#   'date_depot_formate': '29/06/2021',
#   'disponible': True,
#   'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 29-06-2021.pdf',
#   'token': 'QVpFaEI1S2gyMXo2OF9DMDAyMkExMDAxTDQ0NTUyMEQyMDIxMDcwNkgxOTI4NTNUUElKVEVTMDAzUERCT1I',
#   'type': 'Statuts mis à jour',
#   'decision': "Modification relative aux dirigeants d'une société Modification de la forme juridique ou du statut particulier",
#   'date_acte': '2021-05-28',
#   'date_acte_formate': '28/05/2021'},
#  'extrait_immatriculation': {'token': 'SzM0MzAwOTg2Ng'},
#  'association': None}

# %%
# Export data to json file
import json

with open('data/adecco_training.json', 'w') as outfile:
    json.dump(data, outfile)

# %% [markdown]
# # Word filling

# %%
# Open json file
with open('data/google.json') as json_file:
    data = json.load(json_file)

# %%
data
# Out:
# {'siren': '343009866',
#  'siren_formate': '343 009 866',
#  'diffusable': True,
#  'nom_entreprise': 'ADECCO TRAINING',
#  'personne_morale': True,
#  'denomination': 'ADECCO TRAINING',
#  'sigle': None,
#  'nom': None,
#  'prenom': None,
#  'sexe': None,
#  'siege': {'siret': '34300986600611',
#   'siret_formate': '343 009 866 00611',
#   'diffusion_partielle': False,
#   'nic': '00611',
#   'numero_voie': 2,
#   'indice_repetition': None,
#   'type_voie': 'RUE',
#   'libelle_voie': 'HENRI LEGAY',
#   'complement_adresse': None,
#   'adresse_ligne_1': '2 RUE HENRI LEGAY',
#   'adresse_ligne_2': None,
#   'code_postal': '69100',
#   'ville': 'VILLEURBANNE',
#   'pays': 'France',
#   'code_pays': 'FR',
#   'latitude': 45.759053,
#   'longitude': 4.916103,
#   'code_naf': '85.59A',
#   'libelle_code_naf': "Formation continue d'adultes",
#   'date_de_creation': '2016-10-03',
#   'etablissement_employeur': True,
#   'effectif': 'Entre 20 et 49 salariés',
#   'effectif_min': 20,
#   'effectif_max': 49,
#   'tranche_effectif': '12',
#   'annee_effectif': 2020,
#   'etablissement_cesse': False,
#   'date_cessation': None,
#   'domiciliation': None,
#   'siege': True,
#   'enseigne': 'ADECCO TRAINING',
#   'nom_commercial': 'ADECCO TRAINING',
#   'predecesseurs': [{'siret': '34300986600405',
#     'date': '2016-12-01',
#     'transfert_siege': True,
#     'continuite_economique': True}]},
#  'rnm': None,
#  'code_naf': '85.59A',
#  'libelle_code_naf': "Formation continue d'adultes",
#  'domaine_activite': 'Enseignement',
#  'objet_social': "Directement ou indirectement l'activité de formation et de perfectionnement du personnel des entreprises, incluant la formation par l'apprentissage, la création et la gestion d'un centre de formation d'apprentis et d'unités de formation d'apprentissage. Formation des élus et des collectivités territoriales. Prestations de conseil et d'assistance.",
#  'conventions_collectives': [{'nom': 'Convention collective nationale des organismes de formation',
#    'idcc': 1516,
#    'confirmee': True},
#   {'nom': 'Accord national professionnel relatif aux salariés permanents des entreprises de travail temporaire',
#    'idcc': 1413,
#    'confirmee': True},
#   {'nom': 'Convention collective nationale du personnel des prestataires de services dans le domaine du secteur tertiaire',
#    'idcc': 2098,
#    'confirmee': True}],
#  'date_creation': '1987-10-05',
#  'date_creation_formate': '05/10/1987',
#  'entreprise_cessee': False,
#  'date_cessation': None,
#  'date_cessation_formate': None,
#  'associe_unique': False,
#  'categorie_juridique': '5710',
#  'forme_juridique': 'SAS, société par actions simplifiée',
#  'entreprise_employeuse': True,
#  'societe_a_mission': False,
#  'effectif': 'Entre 100 et 199 salariés',
#  'effectif_min': 100,
#  'effectif_max': 199,
#  'annee_effectif': 2020,
#  'tranche_effectif': '22',
#  'annee_tranche_effectif': 2020,
#  'capital': 1857820,
#  'capital_actuel_si_variable': None,
#  'devise_capital': 'Euros',
#  'capital_formate': '1 857 820,00 €',
#  'date_cloture_exercice': '31 Décembre',
#  'date_cloture_exercice_exceptionnelle': None,
#  'prochaine_date_cloture_exercice': '2023-12-31',
#  'prochaine_date_cloture_exercice_formate': '31/12/2023',
#  'economie_sociale_solidaire': False,
#  'duree_personne_morale': 99,
#  'derniere_mise_a_jour_sirene': '2023-06-07',
#  'derniere_mise_a_jour_rcs': None,
#  'dernier_traitement': '2023-04-01',
#  'statut_rcs': 'Inscrit',
#  'greffe': 'LYON',
#  'code_greffe': '6901',
#  'numero_rcs': '343 009 866 R.C.S. Lyon',
#  'date_immatriculation_rcs': '1987-11-24',
#  'date_premiere_immatriculation_rcs': '1987-11-24',
#  'date_debut_activite': None,
#  'date_debut_premiere_activite': '1987-10-05',
#  'date_radiation_rcs': None,
#  'numero_tva_intracommunautaire': 'FR66343009866',
#  'etablissement': {'siret': '34300986600611',
#   'siret_formate': '343 009 866 00611',
#   'diffusion_partielle': False,
#   'nic': '00611',
#   'numero_voie': 2,
#   'indice_repetition': None,
#   'type_voie': 'RUE',
#   'libelle_voie': 'HENRI LEGAY',
#   'complement_adresse': None,
#   'adresse_ligne_1': '2 RUE HENRI LEGAY',
#   'adresse_ligne_2': None,
#   'code_postal': '69100',
#   'ville': 'VILLEURBANNE',
#   'pays': 'France',
#   'code_pays': 'FR',
#   'latitude': 45.759053,
#   'longitude': 4.916103,
#   'code_naf': '85.59A',
#   'libelle_code_naf': "Formation continue d'adultes",
#   'etablissement_employeur': True,
#   'effectif': 'Entre 20 et 49 salariés',
#   'effectif_min': 20,
#   'effectif_max': 49,
#   'tranche_effectif': '12',
#   'annee_effectif': 2020,
#   'date_de_creation': '2016-10-03',
#   'etablissement_cesse': False,
#   'date_cessation': None,
#   'domiciliation': None,
#   'siege': True,
#   'enseigne': 'ADECCO TRAINING',
#   'nom_commercial': 'ADECCO TRAINING',
#   'predecesseurs': [{'siret': '34300986600405',
#     'date': '2016-12-01',
#     'transfert_siege': True,
#     'continuite_economique': True}]},
#  'finances': [{'annee': 2021,
#    'date_de_cloture_exercice': '2021-12-31',
#    'duree_exercice': 12,
#    'chiffre_affaires': 61225938,
#    'chiffre_affaires_export': 19250,
#    'resultat': 3460378,
#    'effectif': None,
#    'marge_brute': 61682881,
#    'excedent_brut_exploitation': 5454618,
#    'resultat_exploitation': 5439710,
#    'taux_croissance_chiffre_affaires': 22.6,
#    'taux_marge_brute': 100.7,
#    'taux_marge_EBITDA': 8.9,
#    'taux_marge_operationnelle': 8.9,
#    'BFR_exploitation': -909659,
#    'BFR_hors_exploitation': 16790668,
#    'BFR': 15881009,
#    'BFR_exploitation_jours_CA': -5.4,
#    'BFR_hors_exploitation_jours_CA': 100.1,
#    'BFR_jours_CA': 94.7,
#    'delai_paiement_clients_jours': 61.2,
#    'delai_paiement_fournisseurs_jours': 85.6,
#    'ratio_stock_CA_jours': 0,
#    'capacite_autofinancement': 3753770,
#    'capacite_autofinancement_CA': 6.1,
#    'fonds_roulement_net_global': 15889293,
#    'couverture_BFR': 1,
#    'tresorerie': 8285,
#    'dettes_financieres': None,
#    'capacite_remboursement': 0,
#    'ratio_endettement': 0,
#    'autonomie_financiere': 49.9,
#    'taux_levier': 0,
#    'etat_dettes_1_an_au_plus': None,
#    'liquidite_generale': None,
#    'couverture_dettes': -275.2,
#    'marge_nette': 5.7,
#    'fonds_propres': 17333969,
#    'rentabilite_fonds_propres': 20,
#    'rentabilite_economique': 10,
#    'valeur_ajoutee': 13576219,
#    'valeur_ajoutee_CA': 22.2,
#    'salaires_charges_sociales': 7448938,
#    'salaires_CA': 12.2,
#    'impots_taxes': 414300},
#   {'annee': 2020,
#    'date_de_cloture_exercice': '2020-12-31',
#    'duree_exercice': 12,
#    'chiffre_affaires': 49921592,
#    'resultat': 2381483,
#    'effectif': 106,
#    'chiffre_affaires_export': 62282,
#    'marge_brute': 50183181,
#    'excedent_brut_exploitation': 4062730,
#    'resultat_exploitation': 3999388,
#    'taux_croissance_chiffre_affaires': -2.8,
#    'taux_marge_brute': 100.5,
#    'taux_marge_EBITDA': 8.1,
#    'taux_marge_operationnelle': 8,
#    'BFR_exploitation': 5314664,
#    'BFR_hors_exploitation': 7137297,
#    'BFR': 12451961,
#    'BFR_exploitation_jours_CA': 38.9,
#    'BFR_hors_exploitation_jours_CA': 52.2,
#    'BFR_jours_CA': 91.1,
#    'delai_paiement_clients_jours': 128.9,
#    'delai_paiement_fournisseurs_jours': 115.5,
#    'ratio_stock_CA_jours': 0,
#    'capacite_autofinancement': 2405800,
#    'capacite_autofinancement_CA': 4.8,
#    'fonds_roulement_net_global': 12459195,
#    'couverture_BFR': 1,
#    'tresorerie': 7235,
#    'dettes_financieres': 1470,
#    'capacite_remboursement': 0,
#    'ratio_endettement': 0,
#    'autonomie_financiere': 41.5,
#    'taux_levier': 0,
#    'etat_dettes_1_an_au_plus': None,
#    'liquidite_generale': None,
#    'couverture_dettes': -386.7,
#    'fonds_propres': 13873590,
#    'marge_nette': 4.8,
#    'rentabilite_fonds_propres': 17.2,
#    'rentabilite_economique': 7.1,
#    'valeur_ajoutee': 10995846,
#    'valeur_ajoutee_CA': 22,
#    'salaires_charges_sociales': 6236459,
#    'salaires_CA': 12.5,
#    'impots_taxes': 352003},
#   {'annee': 2019,
#    'date_de_cloture_exercice': '2019-12-31',
#    'duree_exercice': 12,
#    'chiffre_affaires': 51374984,
#    'resultat': 1111971,
#    'effectif': 120,
#    'chiffre_affaires_export': 12729,
#    'marge_brute': 51947608,
#    'excedent_brut_exploitation': 2272045,
#    'resultat_exploitation': 2012202,
#    'taux_croissance_chiffre_affaires': -7.1,
#    'taux_marge_brute': 101.1,
#    'taux_marge_EBITDA': 4.4,
#    'taux_marge_operationnelle': 3.9,
#    'BFR_exploitation': 3991851,
#    'BFR_hors_exploitation': 6123911,
#    'BFR': 10115762,
#    'BFR_exploitation_jours_CA': 28.4,
#    'BFR_hors_exploitation_jours_CA': 43.5,
#    'BFR_jours_CA': 71.9,
#    'delai_paiement_clients_jours': 116.1,
#    'delai_paiement_fournisseurs_jours': 111.2,
#    'ratio_stock_CA_jours': 0,
#    'capacite_autofinancement': 2007760,
#    'capacite_autofinancement_CA': 3.9,
#    'fonds_roulement_net_global': 10115760,
#    'couverture_BFR': 1,
#    'tresorerie': None,
#    'dettes_financieres': 2699,
#    'capacite_remboursement': 0,
#    'ratio_endettement': 0,
#    'autonomie_financiere': 37.5,
#    'taux_levier': 0,
#    'etat_dettes_1_an_au_plus': 18181049,
#    'liquidite_generale': 1.6,
#    'couverture_dettes': 880.6,
#    'fonds_propres': 11492107,
#    'marge_nette': 2.2,
#    'rentabilite_fonds_propres': 9.7,
#    'rentabilite_economique': 3.6,
#    'valeur_ajoutee': 10808293,
#    'valeur_ajoutee_CA': 21,
#    'salaires_charges_sociales': 7810982,
#    'salaires_CA': 15.2,
#    'impots_taxes': 406553},
#   {'annee': 2018,
#    'date_de_cloture_exercice': '2018-12-31',
#    'duree_exercice': 12,
#    'chiffre_affaires': 55306948,
#    'resultat': 662979,
#    'effectif': 131,
#    'chiffre_affaires_export': 21990,
#    'marge_brute': 55947064,
#    'excedent_brut_exploitation': 599607,
#    'resultat_exploitation': 665932,
#    'taux_croissance_chiffre_affaires': -7.6,
#    'taux_marge_brute': 101.2,
#    'taux_marge_EBITDA': 1.1,
#    'taux_marge_operationnelle': 1.2,
#    'BFR_exploitation': 3063399,
#    'BFR_hors_exploitation': 5755782,
#    'BFR': 8819181,
#    'BFR_exploitation_jours_CA': 20.2,
#    'BFR_hors_exploitation_jours_CA': 38,
#    'BFR_jours_CA': 58.2,
#    'delai_paiement_clients_jours': 91.5,
#    'delai_paiement_fournisseurs_jours': 86.4,
#    'ratio_stock_CA_jours': 0,
#    'capacite_autofinancement': 1098270,
#    'capacite_autofinancement_CA': 2,
#    'fonds_roulement_net_global': 8819178,
#    'couverture_BFR': 1,
#    'tresorerie': None,
#    'dettes_financieres': 319417,
#    'capacite_remboursement': 0.3,
#    'ratio_endettement': 0,
#    'autonomie_financiere': 37.5,
#    'taux_levier': 0.5,
#    'etat_dettes_1_an_au_plus': None,
#    'liquidite_generale': None,
#    'couverture_dettes': 7.4,
#    'fonds_propres': 10380135,
#    'marge_nette': 1.2,
#    'rentabilite_fonds_propres': 6.4,
#    'rentabilite_economique': 2.4,
#    'valeur_ajoutee': 9657357,
#    'valeur_ajoutee_CA': 17.5,
#    'salaires_charges_sociales': 8429229,
#    'salaires_CA': 15.2,
#    'impots_taxes': 533803},
#   {'annee': 2017,
#    'date_de_cloture_exercice': '2017-12-31',
#    'duree_exercice': 12,
#    'chiffre_affaires': 59875338,
#    'resultat': 2852645,
#    'effectif': 149,
#    'chiffre_affaires_export': 232979,
#    'marge_brute': 60895166,
#    'excedent_brut_exploitation': 5231784,
#    'resultat_exploitation': 5337735,
#    'taux_croissance_chiffre_affaires': 33.2,
#    'taux_marge_brute': 101.7,
#    'taux_marge_EBITDA': 8.7,
#    'taux_marge_operationnelle': 8.9,
#    'BFR_exploitation': 4939595,
#    'BFR_hors_exploitation': 1808227,
#    'BFR': 6747822,
#    'BFR_exploitation_jours_CA': 30.1,
#    'BFR_hors_exploitation_jours_CA': 11,
#    'BFR_jours_CA': 41.1,
#    'delai_paiement_clients_jours': 110.7,
#    'delai_paiement_fournisseurs_jours': 106.1,
#    'ratio_stock_CA_jours': 0,
#    'capacite_autofinancement': 3549260,
#    'capacite_autofinancement_CA': 5.9,
#    'fonds_roulement_net_global': 6930415,
#    'couverture_BFR': 1,
#    'tresorerie': 182592,
#    'dettes_financieres': 1470,
#    'capacite_remboursement': -0.1,
#    'ratio_endettement': 0,
#    'autonomie_financiere': 31.7,
#    'taux_levier': 0,
#    'etat_dettes_1_an_au_plus': None,
#    'liquidite_generale': None,
#    'couverture_dettes': -18.8,
#    'fonds_propres': 9717156,
#    'marge_nette': 4.8,
#    'rentabilite_fonds_propres': 29.4,
#    'rentabilite_economique': 9.3,
#    'valeur_ajoutee': 14235087,
#    'valeur_ajoutee_CA': 23.8,
#    'salaires_charges_sociales': 8226679,
#    'salaires_CA': 13.7,
#    'impots_taxes': 575729},
#   {'annee': 2016,
#    'date_de_cloture_exercice': '2016-12-31',
#    'duree_exercice': 12,
#    'chiffre_affaires': 44945845,
#    'resultat': 1980758,
#    'effectif': 129,
#    'chiffre_affaires_export': 218041,
#    'marge_brute': 45453363,
#    'excedent_brut_exploitation': 4649672,
#    'resultat_exploitation': 3958915,
#    'taux_croissance_chiffre_affaires': 46.6,
#    'taux_marge_brute': 101.1,
#    'taux_marge_EBITDA': 10.3,
#    'taux_marge_operationnelle': 8.8,
#    'BFR_exploitation': 5924109,
#    'BFR_hors_exploitation': -1852836,
#    'BFR': 4071273,
#    'BFR_exploitation_jours_CA': 48.1,
#    'BFR_hors_exploitation_jours_CA': -15,
#    'BFR_jours_CA': 33.1,
#    'delai_paiement_clients_jours': 127.1,
#    'delai_paiement_fournisseurs_jours': 113.9,
#    'ratio_stock_CA_jours': 0,
#    'capacite_autofinancement': 2831517,
#    'capacite_autofinancement_CA': 6.3,
#    'fonds_roulement_net_global': 4246170,
#    'couverture_BFR': 1,
#    'tresorerie': 174896,
#    'dettes_financieres': 1470,
#    'capacite_remboursement': -0.1,
#    'ratio_endettement': 0,
#    'autonomie_financiere': 27.2,
#    'taux_levier': 0,
#    'etat_dettes_1_an_au_plus': 5113025,
#    'liquidite_generale': 4.3,
#    'couverture_dettes': -19.9,
#    'fonds_propres': 6864510,
#    'marge_nette': 4.4,
#    'rentabilite_fonds_propres': 28.9,
#    'rentabilite_economique': 7.8,
#    'valeur_ajoutee': 13666309,
#    'valeur_ajoutee_CA': 30.4,
#    'salaires_charges_sociales': 8491900,
#    'salaires_CA': 18.9,
#    'impots_taxes': 516668},
#   {'annee': 2015,
#    'date_de_cloture_exercice': '2015-12-31',
#    'duree_exercice': 12,
#    'chiffre_affaires': 30660231,
#    'resultat': 1678387,
#    'effectif': 117,
#    'chiffre_affaires_export': None,
#    'marge_brute': 31381332,
#    'excedent_brut_exploitation': 2787461,
#    'resultat_exploitation': 2383576,
#    'taux_croissance_chiffre_affaires': None,
#    'taux_marge_brute': 102.4,
#    'taux_marge_EBITDA': 9.1,
#    'taux_marge_operationnelle': 7.8,
#    'BFR_exploitation': 4220358,
#    'BFR_hors_exploitation': -1308930,
#    'BFR': 2911428,
#    'BFR_exploitation_jours_CA': 50.2,
#    'BFR_hors_exploitation_jours_CA': -15.6,
#    'BFR_jours_CA': 34.6,
#    'delai_paiement_clients_jours': 103.5,
#    'delai_paiement_fournisseurs_jours': 78.4,
#    'ratio_stock_CA_jours': 0,
#    'capacite_autofinancement': 2308499,
#    'capacite_autofinancement_CA': 7.5,
#    'fonds_roulement_net_global': 2911428,
#    'couverture_BFR': 1,
#    'tresorerie': None,
#    'dettes_financieres': 622466,
#    'capacite_remboursement': 0.3,
#    'ratio_endettement': 0.1,
#    'autonomie_financiere': 30.3,
#    'taux_levier': 0.2,
#    'etat_dettes_1_an_au_plus': None,
#    'liquidite_generale': None,
#    'couverture_dettes': 5.3,
#    'fonds_propres': 4883752,
#    'marge_nette': 5.5,
#    'rentabilite_fonds_propres': 34.4,
#    'rentabilite_economique': 10.4,
#    'valeur_ajoutee': 9533480,
#    'valeur_ajoutee_CA': 31.1,
#    'salaires_charges_sociales': 6678953,
#    'salaires_CA': 21.8,
#    'impots_taxes': 450965}],
#  'representants': [{'qualite': 'Président',
#    'qualites': ['Président'],
#    'personne_morale': False,
#    'date_prise_de_poste': '2022-08-04',
#    'nom': 'VIROS',
#    'prenom': 'Alexander Paul Raymond',
#    'prenom_usuel': 'Alexander',
#    'nom_usage': None,
#    'nom_complet': 'Alexander Paul Raymond VIROS',
#    'sexe': 'M',
#    'date_de_naissance': '1978-01-08',
#    'date_de_naissance_formate': '08/01/1978',
#    'age': 45,
#    'nationalite': 'Française',
#    'code_nationalité': 'FR',
#    'code_nationalite': 'FR',
#    'ville_de_naissance': '72181 Le Mans (72)',
#    'pays_de_naissance': 'France',
#    'code_pays_de_naissance': 'FR',
#    'adresse_ligne_1': None,
#    'adresse_ligne_2': '7 Boulevard du Temple',
#    'adresse_ligne_3': None,
#    'code_postal': '75003',
#    'ville': 'Paris',
#    'pays': 'France',
#    'code_pays': 'FR'},
#   {'qualite': 'Commissaire aux comptes',
#    'qualites': ['Commissaire aux comptes'],
#    'personne_morale': True,
#    'date_prise_de_poste': '2022-08-04',
#    'denomination': 'ERNST & YOUNG et Autres',
#    'siren': '438476913',
#    'nom_complet': 'ERNST & YOUNG et Autres',
#    'forme_juridique': 'Société par actions simplifiée à capital variable',
#    'adresse_ligne_1': None,
#    'adresse_ligne_2': '1 et 2 Place Des Saisons',
#    'adresse_ligne_3': 'Paris la Défense 1',
#    'code_postal': '92400',
#    'ville': 'Courbevoie',
#    'pays': 'France',
#    'code_pays': 'FR'}],
#  'beneficiaires_effectifs': [{'date_greffe': '2022-08-04',
#    'type': 'BE_SOC',
#    'nom': 'VIROS',
#    'nom_usage': None,
#    'prenom': 'Alexander Paul Raymond',
#    'prenom_usuel': 'Alexander',
#    'pseudonyme': None,
#    'sexe': 'M',
#    'nationalite': 'Française',
#    'code_nationalite': 'FR',
#    'date_de_naissance_formatee': '01/1978',
#    'date_de_naissance_complete_formatee': '08/01/1978',
#    'ville_de_naissance': '72181 Le Mans (72)',
#    'pays_de_naissance': 'France',
#    'code_pays_de_naissance': 'FR',
#    'adresse_ligne_1': None,
#    'adresse_ligne_2': '7 Boulevard du Temple',
#    'adresse_ligne_3': None,
#    'code_postal': '75003',
#    'ville': 'Paris',
#    'pays': 'France',
#    'code_pays': 'FR',
#    'pourcentage_parts': None,
#    'pourcentage_parts_directes': None,
#    'pourcentage_parts_indirectes': None,
#    'pourcentage_parts_vocation_titulaire': None,
#    'details_parts_directes': None,
#    'details_parts_indirectes': None,
#    'details_parts_vocation_titulaire': None,
#    'pourcentage_votes': None,
#    'pourcentage_votes_directs': None,
#    'pourcentage_votes_indirect': None,
#    'details_votes_directs': None,
#    'details_votes_indirects': None,
#    'details_societe_de_gestion': None,
#    'detention_pouvoir_decision_ag': False,
#    'detention_pouvoir_nom_membre_conseil_administration': False,
#    'detention_autres_moyens_controle': False,
#    'beneficiaire_representant_legal': True,
#    'representant_legal_placement_sans_gestion_delegation': False}],
#  'depots_actes': [{'date_depot': '2023-02-23',
#    'date_depot_formate': '23/02/2023',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 23-02-2023.pdf',
#    'token': 'QWduSlB1THJhOVRlN19DMDAyMkExMDAxTDIxMzE5N0QyMDIzMDIyOEgxNzUyMjVUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': "Modification relative aux dirigeants d'une société",
#      'date_acte': '2023-01-13',
#      'date_acte_formate': '13/01/2023'}]},
#   {'date_depot': '2022-08-09',
#    'date_depot_formate': '09/08/2022',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 09-08-2022.pdf',
#    'token': 'QWJGb0UzN3BvSzlLcl9DMDAyMkExMDAxTDIxOTI5NkQyMDIyMDgxNkgxNjU0MzdUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale ordinaire",
#      'decision': 'Modification des commissaires aux comptes',
#      'date_acte': '2022-06-30',
#      'date_acte_formate': '30/06/2022'}]},
#   {'date_depot': '2021-10-04',
#    'date_depot_formate': '04/10/2021',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 04-10-2021.pdf',
#    'token': 'QVc0c1V2ZlZxTExJVF9DMDAyMkExMDAxTDM2Mzk4NkQyMDIxMTAwOUgxNzM4NTlUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': "Modification relative aux dirigeants d'une société",
#      'date_acte': '2021-08-31',
#      'date_acte_formate': '31/08/2021'}]},
#   {'date_depot': '2021-06-29',
#    'date_depot_formate': '29/06/2021',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 29-06-2021.pdf',
#    'token': 'QVpFaEI1S2gyMXo2OF9DMDAyMkExMDAxTDQ0NTUyMEQyMDIxMDcwNkgxOTI4NTNUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale extraordinaire",
#      'decision': "Modification relative aux dirigeants d'une société Modification de la forme juridique ou du statut particulier",
#      'date_acte': '2021-05-28',
#      'date_acte_formate': '28/05/2021'},
#     {'type': 'Rapport du commissaire à la transformation',
#      'decision': "Modification relative aux dirigeants d'une société Modification de la forme juridique ou du statut particulier",
#      'date_acte': '2021-05-12',
#      'date_acte_formate': '12/05/2021'},
#     {'type': 'Statuts mis à jour',
#      'decision': "Modification relative aux dirigeants d'une société Modification de la forme juridique ou du statut particulier",
#      'date_acte': '2021-05-28',
#      'date_acte_formate': '28/05/2021'}]},
#   {'date_depot': '2021-04-08',
#    'date_depot_formate': '08/04/2021',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 08-04-2021.pdf',
#    'token': 'QU9sMDNuVnM3QkVMTV9DMDAyMkExMDAxTDAyMjE4M0QyMDIxMDUwN0gxNzEyMjRUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale extraordinaire",
#      'decision': 'Modification des principales activités',
#      'date_acte': '2021-01-21',
#      'date_acte_formate': '21/01/2021'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Modification des principales activités',
#      'date_acte': '2021-01-21',
#      'date_acte_formate': '21/01/2021'}]},
#   {'date_depot': '2021-04-08',
#    'date_depot_formate': '08/04/2021',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 08-04-2021.pdf',
#    'token': 'QVlNaE9xR0FLZ3NReF9DMDAyMkExMDAxTDI5MTM4N0QyMDIxMDQxM0gxODIxMzJUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale extraordinaire",
#      'decision': 'Modification des principales activités',
#      'date_acte': '2021-01-21',
#      'date_acte_formate': '21/01/2021'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Modification des principales activités',
#      'date_acte': '2021-01-21',
#      'date_acte_formate': '21/01/2021'}]},
#   {'date_depot': '2021-04-07',
#    'date_depot_formate': '07/04/2021',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-04-2021.pdf',
#    'token': 'QU8xaHk4dEtFNUFDTV9DMDAyMkExMDAxTDI5MTA2NUQyMDIxMDQxM0gxODA1MDdUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale ordinaire",
#      'decision': "Modification relative aux dirigeants d'une société",
#      'date_acte': '2021-03-01',
#      'date_acte_formate': '01/03/2021'}]},
#   {'date_depot': '2020-11-18',
#    'date_depot_formate': '18/11/2020',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 18-11-2020.pdf',
#    'token': 'QWtNdHpQTTlmb1dLQl9DMDAyMkExMDAxTDAyNjUzN0QyMDIwMTEyNUgwMTM1NDRUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale ordinaire",
#      'decision': "Modification relative aux dirigeants d'une société",
#      'date_acte': '2020-10-05',
#      'date_acte_formate': '05/10/2020'}]},
#   {'date_depot': '2019-05-09',
#    'date_depot_formate': '09/05/2019',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 09-05-2019.pdf',
#    'token': 'QUhOMWRVR29zR21wNl9DMDAyMkExMDAxTDAxNjIzMkQyMDE5MDUxNUgwMTI1NDJUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale extraordinaire",
#      'decision': 'Modification des principales activités',
#      'date_acte': '2019-04-23',
#      'date_acte_formate': '23/04/2019'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Modification des principales activités',
#      'date_acte': '2019-04-23',
#      'date_acte_formate': '23/04/2019'}]},
#   {'date_depot': '2016-12-15',
#    'date_depot_formate': '15/12/2016',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 15-12-2016.pdf',
#    'token': 'QUhZRmVjdFFQNUNoZ19DMDAyMkExMDAxTDM3Nzg4OUQyMDE2MTIyN0gyMDE5MjBUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': 'Transfert siège social et établissement principal Modification des principales activités',
#      'date_acte': '2016-11-14',
#      'date_acte_formate': '14/11/2016'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Transfert siège social et établissement principal Modification des principales activités',
#      'date_acte': '2016-12-01',
#      'date_acte_formate': '01/12/2016'}]},
#   {'date_depot': '2015-12-23',
#    'date_depot_formate': '23/12/2015',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 23-12-2015.pdf',
#    'token': 'QXBDeURncXlqUVFGb19DMDAyMkExMDAxTDcwMjk1NUQyMDE2MDEwNUgxODIxMTFUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale extraordinaire",
#      'decision': 'Modification des statuts',
#      'date_acte': '2015-12-18',
#      'date_acte_formate': '18/12/2015'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Modification des statuts',
#      'date_acte': '2015-12-18',
#      'date_acte_formate': '18/12/2015'}]},
#   {'date_depot': '2015-11-23',
#    'date_depot_formate': '23/11/2015',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 23-11-2015.pdf',
#    'token': 'QUdTZXE0UDJMaDk1MF9DMDAyMkExMDAxTDQyODQ4NUQyMDE1MTIwNUgxNjUwMjlUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': 'Modification de la dénomination de la personne morale',
#      'date_acte': '2015-11-02',
#      'date_acte_formate': '02/11/2015'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Modification de la dénomination de la personne morale',
#      'date_acte': '2015-11-02',
#      'date_acte_formate': '02/11/2015'}]},
#   {'date_depot': '2015-09-24',
#    'date_depot_formate': '24/09/2015',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 24-09-2015.pdf',
#    'token': 'QU00dmVJcXI2anlTYl9DMDAyMkExMDAxTDc4NDk5OEQyMDE1MTAwNkgxNzQwMjlUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': "Modification relative aux dirigeants d'une société",
#      'date_acte': '2015-09-01',
#      'date_acte_formate': '01/09/2015'}]},
#   {'date_depot': '2014-01-22',
#    'date_depot_formate': '22/01/2014',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 22-01-2014.pdf',
#    'token': 'QUlQYmFSbVdablpWRF9DMDAyMkExMDAxTDAwMzEwM0QyMDE0MDIwM0gxMDQ2MjZUUElKVEVTMDAzUERCT1I',
#    'actes': [{'type': "Procès-verbal d'assemblée générale extraordinaire",
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2012-03-07',
#    'date_depot_formate': '07/03/2012',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-03-2012.pdf',
#    'token': 'QTN3WkVzYnJkR2VGSF9SQUNUMl8zNDMwMDk4NjZfNjkwMV8xOTg3QjAyNjE5XzIwMTJfNjU5NTE',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2012-03-07',
#    'date_depot_formate': '07/03/2012',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-03-2012.pdf',
#    'token': 'QUpWdGlWUEs4ZjZyWl9SQUNUMl8zNDMwMDk4NjZfNjkwMV8xOTg3QjAyNjE5XzIwMTJfNjU5NTI',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2011-09-07',
#    'date_depot_formate': '07/09/2011',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-09-2011.pdf',
#    'token': 'QWFtTjJSOWlXVEtLTV9SQUNUMl8zNDMwMDk4NjZfNjkwMV8xOTg3QjAyNjE5XzIwMTFfMjA5NDMx',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': "Extrait de procès-verbal d'assemblée générale mixte",
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Liste des sièges sociaux antérieurs',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2011-09-07',
#    'date_depot_formate': '07/09/2011',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-09-2011.pdf',
#    'token': 'QWF4RWVCemgxQlh1Rl9SQUNUMl8zNDMwMDk4NjZfNjkwMV8xOTg3QjAyNjE5XzIwMTFfMjA5NDMz',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': "Extrait de procès-verbal d'assemblée générale mixte",
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Liste des sièges sociaux antérieurs',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2011-09-07',
#    'date_depot_formate': '07/09/2011',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-09-2011.pdf',
#    'token': 'QWNidnZ4RHJscjZ0UV9SQUNUMl8zNDMwMDk4NjZfNjkwMV8xOTg3QjAyNjE5XzIwMTFfMjA5NDMy',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': "Extrait de procès-verbal d'assemblée générale mixte",
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Liste des sièges sociaux antérieurs',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2011-09-07',
#    'date_depot_formate': '07/09/2011',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-09-2011.pdf',
#    'token': 'QXpMTmFXM3RoWlNUWV9SQUNUMl8zNDMwMDk4NjZfNjkwMV8xOTg3QjAyNjE5XzIwMTFfMjA5NDM0',
#    'actes': [{'type': 'Décision(s) des associés',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': "Extrait de procès-verbal d'assemblée générale mixte",
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Liste des sièges sociaux antérieurs',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': "Transfert de siège social Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2011-03-07',
#    'date_depot_formate': '07/03/2011',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-03-2011.pdf',
#    'token': 'QXR1UlE4b3lPOWFlaF9SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTFfMjE4NTgwMw',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2011-03-07',
#    'date_depot_formate': '07/03/2011',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-03-2011.pdf',
#    'token': 'QXB5TmhEc3lXUWFLQ19SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTFfMjE4NTgwMQ',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2011-03-07',
#    'date_depot_formate': '07/03/2011',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-03-2011.pdf',
#    'token': 'QWJKdklMV3pmQzNCTl9SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTFfMjE4NTgwMg',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2010-12-30',
#    'date_depot_formate': '30/12/2010',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 30-12-2010.pdf',
#    'token': 'QVd5aWdLVlliMVF0al9SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTBfMTE2OTk3MDE',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2010-12-30',
#    'date_depot_formate': '30/12/2010',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 30-12-2010.pdf',
#    'token': 'QXdxMVIzQ0ZTdDdFNF9SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTBfMTE2OTk5MDE',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2010-11-25',
#    'date_depot_formate': '25/11/2010',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 25-11-2010.pdf',
#    'token': 'QTRBTUNxV2xsNXdpU19SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTBfMTA0NTYyMDE',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2010-08-12',
#    'date_depot_formate': '12/08/2010',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 12-08-2010.pdf',
#    'token': 'QUVkWFBRV2JFYkN6Ml9SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTBfNzA2MTYwMg',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2010-08-12',
#    'date_depot_formate': '12/08/2010',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 12-08-2010.pdf',
#    'token': 'QUNGQ1pERnFHRmpqQl9SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTBfNzA2MTYwMQ',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2010-02-25',
#    'date_depot_formate': '25/02/2010',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 25-02-2010.pdf',
#    'token': 'QTVoTEx2eU85QWp0SV9SQUNUMl8zNDMwMDk4NjZfNzUwMV8xOTk2QjAzODU0XzIwMTBfMTg0MzAwMQ',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2009-02-02',
#    'date_depot_formate': '02/02/2009',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 02-02-2009.pdf',
#    'token': 'QWszUG5TVmNvcnJoVV9SQUNUMDkwMTMzMTgzOQ',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2008-01-28',
#    'date_depot_formate': '28/01/2008',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 28-01-2008.pdf',
#    'token': 'QW1TRlgxVGFJNkJhMV9SQUNUMDgwMTAyMjkxNQ',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2007-04-19',
#    'date_depot_formate': '19/04/2007',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 19-04-2007.pdf',
#    'token': 'QWRMVnJzMzhVYXQ1RV9SQUNUMDcwMDA4MTg1NA',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2006-08-03',
#    'date_depot_formate': '03/08/2006',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 03-08-2006.pdf',
#    'token': 'QU5QN1Z3V1VqY3haWV9SQUNUMDYwMDY0NDc3MA',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2006-01-02',
#    'date_depot_formate': '02/01/2006',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 02-01-2006.pdf',
#    'token': 'QW5nVDYzTEdjMjZjWl9SQUNUMDYwMDE4MzUwMQ',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2005-12-09',
#    'date_depot_formate': '09/12/2005',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 09-12-2005.pdf',
#    'token': 'QU5aU1VUU2RmWjVtZV9SQUNUMDUwMDc2MzgyNg',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2005-10-06',
#    'date_depot_formate': '06/10/2005',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 06-10-2005.pdf',
#    'token': 'QVVDVzFmbVdHSlJFSl9SQUNUMDUwMTE0ODk5NQ',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2005-10-06',
#    'date_depot_formate': '06/10/2005',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 06-10-2005.pdf',
#    'token': 'QWxlVVNraGJpN2FOU19SQUNUMDUwMTE0ODk5NA',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2005-01-04',
#    'date_depot_formate': '04/01/2005',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 04-01-2005.pdf',
#    'token': 'QXgxZXVPWkxQSTJ2Z19SQUNUMDUwMDAwMjQ2Mg',
#    'actes': [{'type': 'Document inconnu',
#      'decision': None,
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2004-08-10',
#    'date_depot_formate': '10/08/2004',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 10-08-2004.pdf',
#    'token': 'QUtKWlFrUTlsMlhaaV9SQUNUMDQwMDQ2MTMzOQ',
#    'actes': [{'type': "Procès-verbal d'assemblée générale",
#      'decision': 'Reconstitution des capitaux propres',
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2003-10-02',
#    'date_depot_formate': '02/10/2003',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 02-10-2003.pdf',
#    'token': 'QUM2Slh0aVBnM1B2el9SQUNUMDMwMDkxMzM1Ng',
#    'actes': [{'type': "Procès-verbal d'assemblée générale mixte",
#      'decision': "Continuation de la société malgré les pertes Modification relative aux dirigeants d'une société",
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2002-10-29',
#    'date_depot_formate': '29/10/2002',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 29-10-2002.pdf',
#    'token': 'QVQ5akYzazBQbWlXVl9SQUNUMDIwMTEwNzgzNQ',
#    'actes': [{'type': "Procès-verbal d'assemblée générale ordinaire",
#      'decision': "Modification relative aux dirigeants d'une société Reconstitution des capitaux propres",
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2001-12-07',
#    'date_depot_formate': '07/12/2001',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 07-12-2001.pdf',
#    'token': 'QU1QRlRrZFk3QUhVcF9SQUNUMDIwMDUyNTg2NQ',
#    'actes': [{'type': "Procès-verbal d'assemblée générale extraordinaire",
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Rapport du commissaire aux comptes',
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2001-04-26',
#    'date_depot_formate': '26/04/2001',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 26-04-2001.pdf',
#    'token': 'QWRNcTllelBISlVFeV9SQUNUMDEwMDM0MDk1NQ',
#    'actes': [{'type': "Procès-verbal d'assemblée générale extraordinaire",
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Décision sur la modification du capital social',
#      'date_acte': None,
#      'date_acte_formate': None}]},
#   {'date_depot': '2000-08-08',
#    'date_depot_formate': '08/08/2000',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 08-08-2000.pdf',
#    'token': 'QW9NMUNGbGtBUGw2RF9SQUNUMDAwMDA0MTY1NA',
#    'actes': [{'type': 'Acte',
#      'decision': 'Continuation de la société malgré les pertes',
#      'date_acte': '2000-08-08',
#      'date_acte_formate': '08/08/2000'}]},
#   {'date_depot': '1999-12-15',
#    'date_depot_formate': '15/12/1999',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 15-12-1999.pdf',
#    'token': 'QUlFN0xKcTZCd3hubF9SQUNUMDAwMDM2MzM1MQ',
#    'actes': [{'type': 'Acte',
#      'decision': 'fusion absorption',
#      'date_acte': '1999-12-15',
#      'date_acte_formate': '15/12/1999'},
#     {'type': 'Déclaration de conformité',
#      'decision': 'fusion absorption',
#      'date_acte': '1999-12-15',
#      'date_acte_formate': '15/12/1999'}]},
#   {'date_depot': '1999-03-25',
#    'date_depot_formate': '25/03/1999',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 25-03-1999.pdf',
#    'token': 'QTJIMFVLdUdkVDNDRl9SQUNUOTkwMDIwMzEyMw',
#    'actes': [{'type': 'Acte',
#      'decision': 'Modification des dirigeants, organes de contrôle',
#      'date_acte': '1999-03-25',
#      'date_acte_formate': '25/03/1999'}]},
#   {'date_depot': '1998-11-20',
#    'date_depot_formate': '20/11/1998',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 20-11-1998.pdf',
#    'token': 'QXVBMEFGWjdESkx4dF9SQUNUOTgwMDY1NDg3Mg',
#    'actes': [{'type': 'Acte',
#      'decision': 'Modification dénomination - objet social',
#      'date_acte': '1998-11-20',
#      'date_acte_formate': '20/11/1998'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Modification dénomination - objet social',
#      'date_acte': '1998-11-20',
#      'date_acte_formate': '20/11/1998'}]},
#   {'date_depot': '1998-07-29',
#    'date_depot_formate': '29/07/1998',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 29-07-1998.pdf',
#    'token': 'QWZMV1lWSVN3VUNINl9SQUNUOTgwMDYxNTUwNA',
#    'actes': [{'type': 'Rapport du commissaire aux apports',
#      'decision': 'Rapport commissaire aux apports',
#      'date_acte': '1998-07-29',
#      'date_acte_formate': '29/07/1998'}]},
#   {'date_depot': '1998-07-24',
#    'date_depot_formate': '24/07/1998',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 24-07-1998.pdf',
#    'token': 'QWZkRGFSclptaU9rYl9SQUNUOTgwMDQyNjg3Mg',
#    'actes': [{'type': 'Projet',
#      'decision': 'fusion absorption',
#      'date_acte': '1998-07-24',
#      'date_acte_formate': '24/07/1998'}]},
#   {'date_depot': '1998-06-30',
#    'date_depot_formate': '30/06/1998',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 30-06-1998.pdf',
#    'token': 'QThSMktKS2p4ZjJVbl9SQUNUOTgwMDQ3NTMxMg',
#    'actes': [{'type': 'Acte',
#      'decision': 'Modification des dirigeants, organes de contrôle',
#      'date_acte': '1998-06-30',
#      'date_acte_formate': '30/06/1998'}]},
#   {'date_depot': '1998-06-24',
#    'date_depot_formate': '24/06/1998',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 24-06-1998.pdf',
#    'token': 'QU40RGx6aVZwc1hHWF9SQUNUOTgwMDExODkyOQ',
#    'actes': [{'type': 'Ordonnance du président',
#      'decision': 'Nomination de commissaire aux apports',
#      'date_acte': '1998-06-24',
#      'date_acte_formate': '24/06/1998'}]},
#   {'date_depot': '1997-06-26',
#    'date_depot_formate': '26/06/1997',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 26-06-1997.pdf',
#    'token': 'QXJZMXo0NXRnSVIxcF9SQUNUOTcwMDM2NDgzMQ',
#    'actes': [{'type': 'Acte',
#      'decision': 'Transfert du siège social de la personne morale',
#      'date_acte': '1997-06-26',
#      'date_acte_formate': '26/06/1997'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Transfert du siège social de la personne morale',
#      'date_acte': '1997-06-26',
#      'date_acte_formate': '26/06/1997'}]},
#   {'date_depot': '1996-10-14',
#    'date_depot_formate': '14/10/1996',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 14-10-1996.pdf',
#    'token': 'QUtJZHdoVDVGdFdadF9SQUNUOTYwMDU4MTEwNQ',
#    'actes': [{'type': 'Acte',
#      'decision': 'fusion absorption Décision sur la modification du capital social',
#      'date_acte': '1996-10-14',
#      'date_acte_formate': '14/10/1996'},
#     {'type': 'Déclaration de conformité',
#      'decision': 'fusion absorption Décision sur la modification du capital social',
#      'date_acte': '1996-10-14',
#      'date_acte_formate': '14/10/1996'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'fusion absorption Décision sur la modification du capital social',
#      'date_acte': '1996-10-14',
#      'date_acte_formate': '14/10/1996'}]},
#   {'date_depot': '1996-08-22',
#    'date_depot_formate': '22/08/1996',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 22-08-1996.pdf',
#    'token': 'QVBtVUVzWFdDN2luQl9SQUNUOTYwMDUwOTczMQ',
#    'actes': [{'type': 'Acte',
#      'decision': 'Rapport commissaire aux apports',
#      'date_acte': '1996-08-22',
#      'date_acte_formate': '22/08/1996'},
#     {'type': 'Rapport du commissaire à la fusion',
#      'decision': 'Rapport commissaire aux apports',
#      'date_acte': '1996-08-22',
#      'date_acte_formate': '22/08/1996'}]},
#   {'date_depot': '1996-07-31',
#    'date_depot_formate': '31/07/1996',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 31-07-1996.pdf',
#    'token': 'QWZTSDJ2aG9nYzRvbl9SQUNUOTYwMDQ3MzY4OA',
#    'actes': [{'type': 'Projet',
#      'decision': 'fusion absorption',
#      'date_acte': '1996-07-31',
#      'date_acte_formate': '31/07/1996'}]},
#   {'date_depot': '1996-07-09',
#    'date_depot_formate': '09/07/1996',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 09-07-1996.pdf',
#    'token': 'QU1paVk3THViVTFjcV9SQUNUOTYwMDM4ODg0OA',
#    'actes': [{'type': 'Ordonnance du président',
#      'decision': 'Nomination de commissaire à la fusion',
#      'date_acte': '1996-07-09',
#      'date_acte_formate': '09/07/1996'}]},
#   {'date_depot': '1995-06-30',
#    'date_depot_formate': '30/06/1995',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 30-06-1995.pdf',
#    'token': 'QWdJMDVpOW42S0lra19SQUNUOTUwMDQ1NTA5OQ',
#    'actes': [{'type': 'Acte',
#      'decision': 'Modification des statuts',
#      'date_acte': '1995-06-30',
#      'date_acte_formate': '30/06/1995'},
#     {'type': 'Statuts mis à jour',
#      'decision': 'Modification des statuts',
#      'date_acte': '1995-06-30',
#      'date_acte_formate': '30/06/1995'}]},
#   {'date_depot': '1994-06-24',
#    'date_depot_formate': '24/06/1994',
#    'disponible': True,
#    'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 24-06-1994.pdf',
#    'token': 'QW83NFduMnZTT2d0ZV9SQUNUOTQwMDMyNTgwMA',
#    'actes': [{'type': 'Acte',
# ...
#    'greffe': 'Lyon',
#    'nom_entreprise': 'Adecco Formation',
#    'personne_morale': True,
#    'sigle': None,
#    'denomination': 'Adecco Formation',
#    'nom_commercial': None,
#    'forme_juridique': 'Société à Responsabilité Limitée',
#    'nom': None,
#    'prenom': None,
#    'administration': "DAVY François nom d'usage : DAVY n'est plus gérant. DEHAZE Alain nom d'usage : DEHAZE devient gérant.",
#    'pseudonyme': None,
#    'nationnalite': None,
#    'adresse': '19 rue Louis Guérin 69100 Villeurbanne',
#    'capital': None,
#    'devise_capital': None,
#    'activite': "Assurer soit directement, soit indirectement la formation et le perfectionnement du personnel des entreprises dans le cadre de la Loi 71.575 du 16/7/1971 et de ses décrets d'application dans toutes activités",
#    'date_debut_activite': None,
#    'description': "Nouveau siège. Modification de l'activité. Modification de l'administration."},
#   {'numero_parution': '20110065',
#    'date': '2011-09-26',
#    'numero_annonce': '7902',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'type': 'Dépôt des comptes',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'sigle': None,
#    'denomination': 'Adecco Formation',
#    'forme_juridique': 'Société à responsabilité limitée',
#    'adresse': '5 rue de Milan 75009 Paris',
#    'date_cloture': '2010-12-31',
#    'type_depot': 'Comptes annuels et rapports',
#    'descriptif': None},
#   {'numero_parution': '20110075',
#    'date': '2011-04-15',
#    'numero_annonce': '1420',
#    'annonce_rectificative': False,
#    'bodacc': 'B',
#    'type': 'Modification',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'nom_entreprise': 'Adecco Formation',
#    'personne_morale': True,
#    'sigle': None,
#    'denomination': 'Adecco Formation',
#    'nom_commercial': None,
#    'forme_juridique': 'Société à responsabilité limitée',
#    'nom': None,
#    'prenom': None,
#    'administration': None,
#    'pseudonyme': None,
#    'nationnalite': None,
#    'adresse': '5 rue de Milan 75009 Paris',
#    'capital': 1466700,
#    'devise_capital': 'EUR',
#    'activite': "Assurer, soit directement, soit indirectement la formation et Leperfectionnement du personnel des entreprises dans le cadre de la loi du 16/07/1991 et décrets d'application dans toutes activités",
#    'date_debut_activite': None,
#    'description': "modification survenue sur l'origine du fonds d'un établissement principal"},
#   {'numero_parution': '20110057',
#    'date': '2011-03-22',
#    'numero_annonce': '890',
#    'annonce_rectificative': False,
#    'bodacc': 'B',
#    'type': 'Modification',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'nom_entreprise': 'Adecco Formation',
#    'personne_morale': True,
#    'sigle': None,
#    'denomination': 'Adecco Formation',
#    'nom_commercial': None,
#    'forme_juridique': 'Société à responsabilité limitée',
#    'nom': None,
#    'prenom': None,
#    'administration': None,
#    'pseudonyme': None,
#    'nationnalite': None,
#    'adresse': '5 rue de Milan 75009 Paris',
#    'capital': 1466700,
#    'devise_capital': 'EUR',
#    'activite': None,
#    'date_debut_activite': None,
#    'description': 'modification survenue sur le capital (augmentation)'},
#   {'numero_parution': '20100252',
#    'date': '2010-12-29',
#    'numero_annonce': '1077',
#    'annonce_rectificative': False,
#    'bodacc': 'A',
#    'type': 'Vente',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'nom_entreprise': 'Adecco Formation',
#    'personne_morale': True,
#    'sigle': None,
#    'denomination': 'Adecco Formation',
#    'nom_commercial': None,
#    'forme_juridique': 'Société à Responsabilité Limitée',
#    'nom': None,
#    'prenom': None,
#    'administration': None,
#    'pseudonyme': None,
#    'nationnalite': None,
#    'adresse': '5 rue de Milan 75009 Paris',
#    'capital': None,
#    'devise_capital': None,
#    'activite': "Partie d'activité concernée : Formation",
#    'date_immatriculation': None,
#    'categorie_vente': 'Autre achat, apport, attribution',
#    'date_debut_activite': '2010-01-01',
#    'origine_fonds': "Nouvelle branche d'activité. Fonds acquis par achat au prix stipulé de 140408.87 EUR",
#    'commentaires': "Achat d'une branche d'activité sis 2 Boulevard du 11 Novembre 1918 69100 Villeurbanne pour être exploité 19 rue Louis Guérin 69100 Villeurbanne",
#    'oppositions': 'Pour la correspondance : Adecco Formation, 5 rue de Milan 75009 Paris; pour la validité : Adecco Formation 19 rue Louis Guérin 69100 Villeurbanne',
#    'declaration_creance': None,
#    'publication_legale': 'Tout Lyon, le 11/12/2010',
#    'denomination_ancien_proprietaire': 'AJILON Sales & Marketing',
#    'siren_ancien_proprietaire': '304970031'},
#   {'numero_parution': '20100061',
#    'date': '2010-09-14',
#    'numero_annonce': '6005',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'type': 'Dépôt des comptes',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'sigle': None,
#    'denomination': 'NOVITEC LE MONDE DE LA FORMATION',
#    'forme_juridique': 'Société à responsabilité limitée',
#    'adresse': '5 R DE MILAN 75009 PARIS',
#    'date_cloture': '2009-12-31',
#    'type_depot': 'Comptes annuels et rapports',
#    'descriptif': None},
#   {'numero_parution': '20100167',
#    'date': '2010-08-29',
#    'numero_annonce': '1044',
#    'annonce_rectificative': False,
#    'bodacc': 'B',
#    'type': 'Modification',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'nom_entreprise': 'Adecco Formation',
#    'personne_morale': True,
#    'sigle': None,
#    'denomination': 'Adecco Formation',
#    'nom_commercial': None,
#    'forme_juridique': 'Société à responsabilité limitée',
#    'nom': None,
#    'prenom': None,
#    'administration': 'Commissaire aux comptes titulaire partant : CABINET ORFIS, Commissaire aux comptes suppléant partant : Marcon, Pierre, Commissaire aux comptes suppléant partant : Guenne, Philippe, nomination du Commissaire aux comptes suppléant : AUDITEX',
#    'pseudonyme': None,
#    'nationnalite': None,
#    'adresse': '5 rue de Milan 75009 Paris',
#    'capital': 1464990,
#    'devise_capital': 'EUR',
#    'activite': None,
#    'date_debut_activite': None,
#    'description': "modification survenue sur la dénomination et l'administration"},
#   {'numero_parution': '20100053',
#    'date': '2010-03-17',
#    'numero_annonce': '1279',
#    'annonce_rectificative': False,
#    'bodacc': 'B',
#    'type': 'Modification',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'nom_entreprise': 'NOVITEC LE MONDE DE LA FORMATION',
#    'personne_morale': True,
#    'sigle': None,
#    'denomination': 'NOVITEC LE MONDE DE LA FORMATION',
#    'nom_commercial': None,
#    'forme_juridique': 'Société à responsabilité limitée',
#    'nom': None,
#    'prenom': None,
#    'administration': "Gérant partant : Levy, nom d'usage : Levy-Waitz, Patrick, nomination du Gérant : Davy, Francois",
#    'pseudonyme': None,
#    'nationnalite': None,
#    'adresse': '5 rue de Milan 75009 Paris',
#    'capital': 1464990,
#    'devise_capital': 'EUR',
#    'activite': None,
#    'date_debut_activite': None,
#    'description': "modification survenue sur l'administration"},
#   {'numero_parution': '20090092',
#    'date': '2009-12-09',
#    'numero_annonce': '7026',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'type': 'Dépôt des comptes',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'sigle': None,
#    'denomination': 'NOVITEC LE MONDE DE LA FORMATION',
#    'forme_juridique': 'Société à responsabilité limitée',
#    'adresse': '5 rue de Milan 75009 Paris',
#    'date_cloture': '2008-12-31',
#    'type_depot': 'Comptes annuels et rapports',
#    'descriptif': None},
#   {'numero_parution': '20090036',
#    'date': '2009-02-20',
#    'numero_annonce': '3179',
#    'annonce_rectificative': False,
#    'bodacc': 'B',
#    'type': 'Modification',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'nom_entreprise': 'NOVITEC LE MONDE DE LA FORMATION',
#    'personne_morale': True,
#    'sigle': None,
#    'denomination': 'NOVITEC LE MONDE DE LA FORMATION',
#    'nom_commercial': None,
#    'forme_juridique': 'Société à responsabilité limitée',
#    'nom': None,
#    'prenom': None,
#    'administration': None,
#    'pseudonyme': None,
#    'nationnalite': None,
#    'adresse': '5 rue de Milan 75009 Paris',
#    'capital': 1464990,
#    'devise_capital': 'EUR',
#    'activite': None,
#    'date_debut_activite': None,
#    'description': 'modification survenue sur le capital (augmentation)'},
#   {'numero_parution': '20080073',
#    'date': '2008-09-26',
#    'numero_annonce': '1223',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'type': 'Dépôt des comptes',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'sigle': None,
#    'denomination': 'NOVITEC LE MONDE DE LA FORMATION',
#    'forme_juridique': 'Société à responsabilité limitée',
#    'adresse': '5 rue de Milan 75009 Paris',
#    'date_cloture': '2007-12-31',
#    'type_depot': 'Comptes annuels et rapports',
#    'descriptif': None},
#   {'numero_parution': '20080089',
#    'date': '2008-05-27',
#    'numero_annonce': '1121',
#    'annonce_rectificative': False,
#    'bodacc': 'B',
#    'type': 'Modification',
#    'rcs': 'de Paris',
#    'greffe': 'Paris',
#    'nom_entreprise': 'NOVITEC LE MONDE DE LA FORMATION',
#    'personne_morale': True,
#    'sigle': None,
#    'denomination': 'NOVITEC LE MONDE DE LA FORMATION',
#    'nom_commercial': None,
#    'forme_juridique': 'Société à responsabilité limitée',
#    'nom': None,
#    'prenom': None,
#    'administration': None,
#    'pseudonyme': None,
#    'nationnalite': None,
#    'adresse': '5 rue de Milan 75009 Paris',
#    'capital': 465000,
#    'devise_capital': 'EUR',
#    'activite': None,
#    'date_debut_activite': None,
#    'description': "modification survenue sur l'adresse du siège"}],
#  'publications_shal': [{'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ['Mouvement des Commissaires aux comptes'],
#    'date_parution': '2022-07-30',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Essor Rhône',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ['Mouvement des Dirigeants'],
#    'date_parution': '2021-09-30',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tribune de Lyon',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ['Modification de la Forme juridique',
#     'Mouvement des Dirigeants'],
#    'date_parution': '2021-06-12',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Essor Rhône',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ["Mouvement sur l'activité ou l'Objet social"],
#    'date_parution': '2021-04-03',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Essor Rhône',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ['Mouvement des Dirigeants'],
#    'date_parution': '2021-03-27',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Essor Rhône',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ['Rectificatif / Erratum'],
#    'date_parution': '2020-11-07',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Essor Rhône',
#    'types': ['Annonces diverses']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ['Mouvement des Dirigeants'],
#    'date_parution': '2020-10-24',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Essor Rhône',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ["Mouvement sur l'activité ou l'Objet social"],
#    'date_parution': '2019-05-09',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tribune de Lyon',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ["Modification de l'adresse du Siège social"],
#    'date_parution': '2016-11-24',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tribune de Lyon',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ["Mouvement sur l'activité ou l'Objet social"],
#    'date_parution': '2015-12-26',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Affiches',
#    'types': ['Modification']},
#   {'nom_entreprise': 'Adecco Training',
#    'departement': '69',
#    'evenements': ['Modification de la dénomination'],
#    'date_parution': '2015-11-14',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Affiches',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO FORMATION',
#    'departement': '69',
#    'evenements': ['Mouvement des Dirigeants'],
#    'date_parution': '2015-09-05',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Affiches',
#    'types': ['Modification']},
#   {'nom_entreprise': 'Adecco Formation',
#    'departement': '69',
#    'evenements': ['Réduction de capital social'],
#    'date_parution': '2014-01-04',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon Affiches',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO FORMATION',
#    'departement': '69',
#    'evenements': ['Modification du Capital social'],
#    'date_parution': '2012-02-25',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon (Le)',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO FORMATION',
#    'departement': '69',
#    'evenements': ["Modification de l'adresse du Siège social",
#     'Mouvement des Dirigeants'],
#    'date_parution': '2011-07-23',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Tout Lyon (Le)',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO FORMATION',
#    'departement': '69',
#    'evenements': ["Modification de l'adresse du Siège social"],
#    'date_parution': '2011-07-16',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Affiches parisiennes (Les)',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO FORMATION',
#    'departement': '75',
#    'evenements': ['Modification de la dénomination',
#     'Mouvement des Dirigeants'],
#    'date_parution': '2010-06-08',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Petites Affiches (Les) - La Loi - Le Quotidien Juridique - Gazette du Palais',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO FORMATION',
#    'departement': '75',
#    'evenements': ['Modification de la dénomination'],
#    'date_parution': '2010-06-08',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Petites Affiches (Les) - La Loi - Le Quotidien Juridique - Gazette du Palais',
#    'types': ['Modification']},
#   {'nom_entreprise': 'NOVITEC LE MONDE DE LA FORMATION',
#    'departement': '75',
#    'evenements': ['Mouvement des Dirigeants'],
#    'date_parution': '2010-01-19',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Petites Affiches (Les) - La Loi - Le Quotidien Juridique - Gazette du Palais',
#    'types': ['Modification']},
#   {'nom_entreprise': 'ADECCO TRAINING',
#    'departement': '69',
#    'evenements': ['Mouvement des Dirigeants'],
#    'date_parution': '2023-02-22',
#    'code_postal': '69100',
#    'ville': 'VILLEURBANNE',
#    'journal': 'Ouest France WEB',
#    'types': ['Modification']}],
#  'procedures_collectives': [],
#  'procedure_collective_existe': False,
#  'procedure_collective_en_cours': False,
#  'derniers_statuts': {'date_depot': '2021-06-29',
#   'date_depot_formate': '29/06/2021',
#   'disponible': True,
#   'nom_fichier_pdf': 'ADECCO TRAINING - Actes du 29-06-2021.pdf',
#   'token': 'QVpFaEI1S2gyMXo2OF9DMDAyMkExMDAxTDQ0NTUyMEQyMDIxMDcwNkgxOTI4NTNUUElKVEVTMDAzUERCT1I',
#   'type': 'Statuts mis à jour',
#   'decision': "Modification relative aux dirigeants d'une société Modification de la forme juridique ou du statut particulier",
#   'date_acte': '2021-05-28',
#   'date_acte_formate': '28/05/2021'},
#  'extrait_immatriculation': {'token': 'SzM0MzAwOTg2Ng'},
#  'association': None}

# %%
[el for el in data.keys() if 'juridi' in el]
# Out:
# ['categorie_juridique', 'forme_juridique']

# %%
data['forme_juridique']
# Out:
# 'EURL, entreprise unipersonnelle à responsabilité limitée'

# %%
# !pip install python-docx
# Out:
# Collecting python-docx
#   Using cached python_docx-0.8.11-py3-none-any.whl
# Requirement already satisfied: lxml>=2.3.2 in /Users/camilleepitalon/miniconda3/envs/llm/lib/python3.10/site-packages (from python-docx) (4.9.2)
# Installing collected packages: python-docx
# Successfully installed python-docx-0.8.11

# %%
from docx import Document
from docx.shared import Pt
import docx2pdf

# %%
[el for el in data.keys() if 'rcs' in el]
# Out:
# ['derniere_mise_a_jour_rcs',
#  'statut_rcs',
#  'numero_rcs',
#  'date_immatriculation_rcs',
#  'date_premiere_immatriculation_rcs',
#  'date_radiation_rcs']

# %%
[el for el in data.keys() if 'exercice' in el]
# Out:
# ['date_cloture_exercice',
#  'date_cloture_exercice_exceptionnelle',
#  'prochaine_date_cloture_exercice',
#  'prochaine_date_cloture_exercice_formate']

# %%
# Out:
# '01 janvier au 31 décembre'

# %%
# Convert "31 décembre" to date
from datetime import datetime

datetime.strptime(data['date_cloture_exercice'], '%Y-%m-%d')

# Find date de début d'exercice
from datetime import timedelta

date_debut_exercice = datetime.strptime(data['date_cloture_exercice'], '%Y-%m-%d') - timedelta(days=365)
date_debut_exercice
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 4
#       1 # Convert to date
#       2 from datetime import datetime
# ----> 4 datetime.strptime(data['date_cloture_exercice'], '%Y-%m-%d')
#       6 # Find date de début d'exercice
#       7 from datetime import timedelta
#
# File ~/miniconda3/envs/llm/lib/python3.10/_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File ~/miniconda3/envs/llm/lib/python3.10/_strptime.py:349, in _strptime(data_string, format)
#     347 found = format_regex.match(data_string)
#     348 if not found:
# --> 349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
#     352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#
# ValueError: time data '31 Décembre' does not match format '%Y-%m-%d'

# %%
data['representants']
# Out:
# [{'qualite': 'Président',
#   'qualites': ['Président'],
#   'personne_morale': False,
#   'date_prise_de_poste': '2022-08-04',
#   'nom': 'VIROS',
#   'prenom': 'Alexander Paul Raymond',
#   'prenom_usuel': 'Alexander',
#   'nom_usage': None,
#   'nom_complet': 'Alexander Paul Raymond VIROS',
#   'sexe': 'M',
#   'date_de_naissance': '1978-01-08',
#   'date_de_naissance_formate': '08/01/1978',
#   'age': 45,
#   'nationalite': 'Française',
#   'code_nationalité': 'FR',
#   'code_nationalite': 'FR',
#   'ville_de_naissance': '72181 Le Mans (72)',
#   'pays_de_naissance': 'France',
#   'code_pays_de_naissance': 'FR',
#   'adresse_ligne_1': None,
#   'adresse_ligne_2': '7 Boulevard du Temple',
#   'adresse_ligne_3': None,
#   'code_postal': '75003',
#   'ville': 'Paris',
#   'pays': 'France',
#   'code_pays': 'FR'},
#  {'qualite': 'Commissaire aux comptes',
#   'qualites': ['Commissaire aux comptes'],
#   'personne_morale': True,
#   'date_prise_de_poste': '2022-08-04',
#   'denomination': 'ERNST & YOUNG et Autres',
#   'siren': '438476913',
#   'nom_complet': 'ERNST & YOUNG et Autres',
#   'forme_juridique': 'Société par actions simplifiée à capital variable',
#   'adresse_ligne_1': None,
#   'adresse_ligne_2': '1 et 2 Place Des Saisons',
#   'adresse_ligne_3': 'Paris la Défense 1',
#   'code_postal': '92400',
#   'ville': 'Courbevoie',
#   'pays': 'France',
#   'code_pays': 'FR'}]

# %%
# Out:
# 'Principals: ERNST & YOUNG ET AUTRES (438476913)'

# %%
# Create distribution of dividends
three_lastest_exercices = [el['annee'] for el in data['finances']]
three_lastest_exercices.sort(reverse=True)
three_lastest_exercices = three_lastest_exercices[:3]
three_lastest_exercices

distribution_of_dividends = {
    'year_1': three_lastest_exercices[0],
    'net_income_1': str([el['chiffre_affaires'] for el in data['finances'] if el['annee'] == three_lastest_exercices[0]][0]),
    'dividents_1': '',
    'distribution_date_1': '',
    'year_2': three_lastest_exercices[1],
    'net_income_2': str([el['chiffre_affaires'] for el in data['finances'] if el['annee'] == three_lastest_exercices[1]][0]),
    'dividents_2': '',
    'distribution_date_2': '',
    'year_3': three_lastest_exercices[2],
    'net_income_3': str([el['chiffre_affaires'] for el in data['finances'] if el['annee'] == three_lastest_exercices[2]][0]),
    'dividents_3': '',
    'distribution_date_3': ''
}

distribution_of_dividents
# Out:
# {'year_1': 2021,
#  'net_income_1': '592480368',
#  'dividents_1': '',
#  'distribution_date_1': '',
#  'year_2': 2020,
#  'net_income_2': '567516085',
#  'dividents_2': '',
#  'distribution_date_2': '',
#  'year_3': 2019,
#  'net_income_3': '483033598',
#  'dividents_3': '',
#  'distribution_date_3': ''}

# %%
[el for el in data['finances'] if el['annee'] == max([el['annee'] for el in data['finances']])]
# Out:
# [{'annee': 2021,
#   'date_de_cloture_exercice': '2021-12-31',
#   'duree_exercice': 12,
#   'chiffre_affaires': 592480368,
#   'chiffre_affaires_export': 592480368,
#   'resultat': 80405308,
#   'effectif': None,
#   'marge_brute': 592513154,
#   'excedent_brut_exploitation': 113677293,
#   'resultat_exploitation': 96402045,
#   'taux_croissance_chiffre_affaires': 4.4,
#   'taux_marge_brute': 100,
#   'taux_marge_EBITDA': 19.2,
#   'taux_marge_operationnelle': 16.3,
#   'BFR_exploitation': -64262759,
#   'BFR_hors_exploitation': 85611619,
#   'BFR': 21348860,
#   'BFR_exploitation_jours_CA': -39.6,
#   'BFR_hors_exploitation_jours_CA': 52.7,
#   'BFR_jours_CA': 13.1,
#   'delai_paiement_clients_jours': 0,
#   'delai_paiement_fournisseurs_jours': 146.9,
#   'ratio_stock_CA_jours': 0,
#   'capacite_autofinancement': 97746575,
#   'capacite_autofinancement_CA': 16.5,
#   'fonds_roulement_net_global': 21386189,
#   'couverture_BFR': 1,
#   'tresorerie': None,
#   'dettes_financieres': 9006296,
#   'capacite_remboursement': 0.1,
#   'ratio_endettement': 0,
#   'autonomie_financiere': 48.6,
#   'taux_levier': 0.1,
#   'etat_dettes_1_an_au_plus': 238979500,
#   'liquidite_generale': 1.1,
#   'couverture_dettes': 24.1,
#   'marge_nette': 13.6,
#   'fonds_propres': 227510209,
#   'rentabilite_fonds_propres': 35.3,
#   'rentabilite_economique': 17.2,
#   'valeur_ajoutee': 432792998,
#   'valeur_ajoutee_CA': 73,
#   'salaires_charges_sociales': 304544810,
#   'salaires_CA': 51.4,
#   'impots_taxes': 14484407}]

# %%
[el for el in data['finances'].keys() if 'finances' in el]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 [el for el in data['finances'].keys() if 'finances' in el]
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
data['derniere_mise_a_jour_sirene']
# Out:
# '2023-06-08'

# %%
doc = Document('assets/template_fiche_societe.docx')

# Create fiscal year
locale.setlocale(locale.LC_TIME, "fr_FR")
end_date = datetime.datetime.strptime(data['date_cloture_exercice'], "%d %B").strftime("%d %B")
start_date = (datetime.datetime.strptime(data['date_cloture_exercice'], "%d %B") + datetime.timedelta(days=1)).strftime("%d %B")
fiscal_year = f'{start_date} au {end_date}'

# Create distribution of dividends
lastest_exercices = [el['annee'] for el in data['finances']]
lastest_exercices.sort(reverse=True)
if len(three_lastest_exercices) >= 3:
    three_lastest_exercices = lastest_exercices[:3]
    distribution_of_dividends = {
        'year_1': str(three_lastest_exercices[0]),
        'net_income_1': str([el['chiffre_affaires'] for el in data['finances'] if el['annee'] == three_lastest_exercices[0]][0]),
        'dividends_1': '', 'distribution_date_1': '',
        'year_2': str(three_lastest_exercices[1]),
        'net_income_2': str([el['chiffre_affaires'] for el in data['finances'] if el['annee'] == three_lastest_exercices[1]][0]),
        'dividends_2': '', 'distribution_date_2': '',
        'year_3': str(three_lastest_exercices[2]),
        'net_income_3': str([el['chiffre_affaires'] for el in data['finances'] if el['annee'] == three_lastest_exercices[2]][0]),
        'dividends_3': '', 'distribution_date_3': ''
    }
elif len(three_lastest_exercices) == 2:
    two_lastest_exercices = lastest_exercices[:2]
    distribution_of_dividends = {
        'year_1': two_lastest_exercices[0],
        'net_income_1': str([el['chiffre_affaires'] for el in data['finances'] if el['annee'] == two_lastest_exercices[0]][0]),
        'dividends_1': '', 'distribution_date_1': '',
        'year_2': two_lastest_exercices[1],
        'net_income_2': str([el['chiffre_affaires'] for el in data['finances'] if el['annee'] == two_lastest_exercices[1]][0]),
        'dividends_2': '', 'distribution_date_2': '', 'year_3': '', 'net_income_3': '', 'dividends_3': '', 'distribution_date_3': ''
    }
elif len(three_lastest_exercices) == 1:
    lastest_exercice = lastest_exercices[0]
    distribution_of_dividends = {
        'year_1': lastest_exercice,
        'net_income_1': str([el['chiffre_affaires'] for el in data['finances'] if el['annee'] == lastest_exercice][0]),
        'dividends_1': '', 'distribution_date_1': '', 'year_2': '', 'net_income_2': '', 'dividends_2': '', 
        'distribution_date_2': '', 'year_3': '', 'net_income_3': '', 'dividends_3': '', 'distribution_date_3': ''
    }
else:
    distribution_of_dividends = {
        'year_1': '', 'net_income_1': '', 'dividends_1': '', 'distribution_date_1': '', 'year_2': '', 'net_income_2': '', 'dividends_2': '', 
        'distribution_date_2': '', 'year_3': '', 'net_income_3': '', 'dividends_3': '', 'distribution_date_3': ''
    }


replacements = {
    'country': data['siege']['pays'],
    'company_name': data['nom_entreprise'],
    'corporate_form': data['forme_juridique'],
    'registered_office': data['siege']['adresse_ligne_1'] + ', ' + data['siege']['code_postal'] + ', ' + data['siege']['ville'] + ', ' + data['siege']['pays'],
    'share_capital': data['capital_formate'],
    # 'issued_shares': 'Not provided',
    # 'shareholding': 'Not provided',
    'registration_number': data['siren_formate'],
    'rcs_inscription': f"{data['statut_rcs']} (au greffe de {data['greffe']}, le {data['date_immatriculation_rcs']})",
    'company_purpose': data['objet_social'],
    'term': (datetime.datetime.strptime(data['date_immatriculation_rcs'], '%Y-%m-%d') + datetime.timedelta(days=data['duree_personne_morale']*365)).strftime('%Y-%m-%d'),
    'fiscal_year': fiscal_year,
    # 'management_president': [x for x in data['representants'] if x['qualite'] == 'Président'][0]['nom_complet'],
    # 'management_board_of_directors': [x['nom_complet'] for x in data['representants'] if x['qualite'] == 'Gérant'],
    'management': ", ".join([f"{el['nom_complet']} ({el['qualite']})" for el in data['representants'] if 'Commissaire aux comptes' not in el['qualite']]),
    'statutory_auditors_principals': "Principals: " + " ".join([f"{el['nom_complet']} ({el['siren']})" for el in data['representants'] if 'Commissaire aux comptes titulaire' in el['qualite']]),
    'statutory_auditors_alternates': "Alternates: " + " ".join([f"{el['nom_complet']} ({el['siren']})" for el in data['representants'] if el['qualite'] == 'Commissaire aux comptes suppléant']),
    # 'statutory_restrictions_on_transfer_of_shares': 'Not provided',
    # 'powers_restriction_board_of_directors_reserved_matters': 'Not provided',
    # 'other_securities_giving_access_to_the_share_capital': 'Not provided',
    # 'pledge_over_securities': 'Not provided',
    'year1': distribution_of_dividends['year_1'],
    'net_income1': distribution_of_dividends['net_income_1'],
    'dividends1': distribution_of_dividends['dividends_1'],
    'distributiondate1': distribution_of_dividends['distribution_date_1'],
    'year2': distribution_of_dividends['year_2'],
    'net_income2': distribution_of_dividends['net_income_2'],
    'dividends2': distribution_of_dividends['dividends_2'],
    'distributiondate2': distribution_of_dividends['distribution_date_2'],
    'year3': distribution_of_dividends['year_3'],
    'net_income3': distribution_of_dividends['net_income_3'],
    'dividends3': distribution_of_dividends['dividends_3'],
    'distributiondate3': distribution_of_dividends['distribution_date_3'],
    'date_of_updated_articles_of_association': data['derniere_mise_a_jour_sirene']
}

for paragraph in doc.paragraphs:
    for key, value in replacements.items():
        if key in paragraph.text:
            for run in paragraph.runs:
                if key in run.text:
                    run.text = run.text.replace(key, value)
                    run.font.name = 'Arial'
                    run.font.size = Pt(8)
                    run.font.bold = True

for table in doc.tables:
    for row in table.rows:
        for cell in row.cells:
            for key, value in replacements.items():
                if key in cell.text:
                    # Replace the field and set font style and size
                    paragraphs = cell.paragraphs
                    for paragraph in paragraphs:
                        run = paragraph.runs
                        for i in range(len(run)):
                            if key in run[i].text:
                                run[i].text = run[i].text.replace(key, value)
                                run[i].font.name = 'Arial'
                                run[i].font.size = Pt(8)


doc.save('results/filled_document.docx')
